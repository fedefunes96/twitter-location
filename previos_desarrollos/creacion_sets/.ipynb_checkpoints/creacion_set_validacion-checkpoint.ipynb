# %%
import pandas as pd
import psycopg2
import pandas.io.sql as psql
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point
from statsmodels.distributions.empirical_distribution import ECDF
import seaborn as sns
from matplotlib import ticker
from shapely.geometry import Polygon, box
from sqlalchemy import create_engine
from sklearn.neighbors import BallTree

dosTPath = "../../../../../dosT/ffunes/"
unTPath = "../../../../../unT/ffunes/"
figuresPath = unTPath + "figures/"

# %matplotlib inline

sns.set_theme()

# %%
try:
    conn = psycopg2.connect(user = "ffunes",
                            password = "location8",
                            host = "127.0.0.1",
                            port = "5432",
                            database = "elecciones_twitter")
except Exception as e:
    print("No se pudo conectar a la base de datos")

# %% [markdown]
# ¿Cuantos Tweets tenemos?

# %%
pd.read_sql_query('SELECT COUNT(*) FROM tweets',con=conn)
# Out:
#        count
# 0  897531026

# %% [markdown]
# ¿Cuantos Tweets tenemos que incluyan bounding box?

# %%
pd.read_sql_query('SELECT COUNT(*) FROM tweets WHERE place_bounding_box IS NOT NULL',con=conn)
# Out:
#       count
# 0  17523907

# %% [markdown]
# ¿Cuantos Tweets tenemos que incluyan coordenadas exactas?

# %%
pd.read_sql_query('SELECT COUNT(*) FROM tweets WHERE coordinates IS NOT NULL',con=conn)
# Out:
#      count
# 0  1022033

# %% [markdown]
# ¿Cuantos Tweets tenemos que incluyen un lugar de tipo ciudad?

# %%
pd.read_sql_query("SELECT COUNT(*) FROM tweets WHERE place_type='city'",con=conn)
# Out:
#       count
# 0  14333550

# %%
pd.read_sql_query("SELECT MIN(date), MAX(date) FROM tweets",con=conn)
# Out:
#                   min                 max
# 0 2019-01-01 02:59:59 2019-12-11 00:11:21

# %% [markdown]
# Consideremos ahora todos los tweets de los usuarios sobre los cuales poseemos coordenadas específicas

# %%
pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets AS tw\
    INNER JOIN (SELECT user_id from tweets WHERE coordinates IS NOT NULL) AS us_geo\
    ON tw.user_id=us_geo.user_id"
    , con=conn)
# Out:
#       count
# 0  47974143

# %%
c = pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets WHERE user_id IN (SELECT id from users_location_exact)"
    , con=conn)

# %%
c
# Out:
#       count
# 0  27574343

# %%
b = pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets WHERE user_id IN (SELECT id from users_location_exact) AND coordinates IS NOT NULL"
    , con=conn)

# %%
b
# Out:
#     count
# 0  625180

# %%
pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets WHERE user_id IN (SELECT DISTINCT user_id from tweets WHERE coordinates IS NOT NULL)"
    , con=conn)

# %%
c = pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets WHERE user_id IN (SELECT id from users_location_bbox)"
    , con=conn)

# %%
c
# Out:
#        count
# 0  124192146

# %%
pd.read_sql_query(
    "SELECT COUNT(*) FROM tweets WHERE user_id IN (SELECT DISTINCT user_id from tweets WHERE place_bounding_box IS NOT NULL)"
    , con=conn)
# Out:
#        count
# 0  186896278

# %% [markdown]
# Cargamos los Tweets geolocalizados (Que incluyen un "Bounding Box") -> tweets_with_geo.
# Hay que analizar el campo "coordinates" que es una coordenada precisa siempre y cuando haya tweets que contengan "coordinates" pero no "Bounding Box"

# %%
tweets_with_geo_bbox = gpd.GeoDataFrame.from_postgis(
    'SELECT id, user_id, full_text, place_type, place_name, place_country, place_bounding_box, date FROM tweets WHERE place_bounding_box IS NOT NULL'
    , con=conn 
    , geom_col='place_bounding_box'
)

# %%
tweets_with_geo_bbox.head(2)
# Out:
#                     id    user_id  \
# 0  1168568904207278081  189612419
# 1  1168568425020633088  189612419
#
#                                            full_text place_type  \
# 0  @gracepenafort @diegobossio Espero, porque con...       city
# 1               @sergioVillone Me encanto, 👏👏👏 Berco       city
#
#                         place_name place_country  \
# 0  Ciudad Autónoma de Buenos Aires     Argentina
# 1  Ciudad Autónoma de Buenos Aires     Argentina
#
#                                   place_bounding_box                date
# 0  POLYGON ((-58.53179 -34.67445, -58.35349 -34.6... 2019-09-02 16:58:32
# 1  POLYGON ((-58.53179 -34.67445, -58.35349 -34.6... 2019-09-02 16:56:38

# %%
tweets_with_geo_bbox.place_type.value_counts()
# Out:
# city            14333531
# admin            2524165
# country           510316
# poi               149729
# neighborhood        6166
# Name: place_type, dtype: int64

# %% [markdown]
# Por ahora nos importan solo las ciudades

# %%
tweets_with_geo_bbox = tweets_with_geo_bbox.loc[tweets_with_geo_bbox["place_type"] == "city", :]

# %%
tweets_with_geo_bbox.shape
# Out:
# (14333531, 8)

# %% [markdown]
# Pasamos a minúsculas los campos de texto que nos importan Update: Intentamos sacar los acentos también

# %%
#import unidecode

def to_lower(row, column):
    if not type(row[column] == str):
        return row[column]
    
    return str(row[column]).lower()
    #return unidecode.unidecode(str(row[column]).lower())

# %%
tweets_with_geo_bbox["place_name"] = tweets_with_geo_bbox.apply(to_lower, axis=1, column="place_name")
tweets_with_geo_bbox["place_country"] = tweets_with_geo_bbox.apply(to_lower, axis=1, column="place_country")

# %%
tweets_with_geo_bbox.head(2)
# Out:
#                     id    user_id  \
# 0  1168568904207278081  189612419
# 1  1168568425020633088  189612419
#
#                                            full_text place_type  \
# 0  @gracepenafort @diegobossio Espero, porque con...       city
# 1               @sergioVillone Me encanto, 👏👏👏 Berco       city
#
#                         place_name place_country  \
# 0  ciudad autónoma de buenos aires     argentina
# 1  ciudad autónoma de buenos aires     argentina
#
#                                   place_bounding_box                date
# 0  POLYGON ((-58.53179 -34.67445, -58.35349 -34.6... 2019-09-02 16:58:32
# 1  POLYGON ((-58.53179 -34.67445, -58.35349 -34.6... 2019-09-02 16:56:38

# %%
tweets_with_geo_bbox["longitude_centroid"] = tweets_with_geo_bbox.geometry.centroid.x
tweets_with_geo_bbox["latitude_centroid"] = tweets_with_geo_bbox.geometry.centroid.y

# %%
tweets_with_geo_bbox.shape
# Out:
# (14333531, 10)

# %%
#tweets_with_geo_bbox.to_csv('../../../../../unT/ffunes/tweets_with_bbox.csv')
tweets_with_geo_bbox.to_pickle('../../../../../unT/ffunes/bounding_box/tweets_with_bbox.pkl')

# %%
#tweets_with_geo.to_pickle('../../../../../dosT/ffunes/tweets_with_geolocalization.pkl')

# %% [markdown]
# Coordenadas especificas

# %%
tweets_with_geo_exact = gpd.GeoDataFrame.from_postgis(
    'SELECT id, user_id, full_text, place_type, place_name, place_country, coordinates, date FROM tweets WHERE coordinates IS NOT NULL'
    , con=conn 
    , geom_col='coordinates'
)

# %%
tweets_with_geo_exact["place_name"] = tweets_with_geo_exact.apply(to_lower, axis=1, column="place_name")
tweets_with_geo_exact["place_country"] = tweets_with_geo_exact.apply(to_lower, axis=1, column="place_country")

# %%
tweets_with_geo_exact["user_id"].nunique()
# Out:
# 67855

# %%
tweets_with_geo_exact.head(2)
# Out:
#                     id     user_id  \
# 0  1127626979820408832   772771614
# 1  1115020518837628928  2229231199
#
#                                            full_text place_type  \
# 0  Un par de fotos de lo que dejó @dubfire Por su...       city
# 1  acá también en Ciudad Autónoma de Buenos Aires...       city
#
#                         place_name place_country                  coordinates  \
# 0                          córdoba     argentina  POINT (-64.15934 -31.39297)
# 1  ciudad autónoma de buenos aires     argentina  POINT (-58.43970 -34.60890)
#
#                  date
# 0 2019-05-12 17:29:56
# 1 2019-04-07 22:36:22

# %%
tweets_with_geo_exact["latitude"] = tweets_with_geo_exact["coordinates"].y
tweets_with_geo_exact["longitude"] = tweets_with_geo_exact["coordinates"].x

# %%
tweets_with_geo_exact["place_type"].value_counts()
# Out:
# city            856978
# admin           138457
# country          22552
# poi               1079
# neighborhood       312
# Name: place_type, dtype: int64

# %%
#tweets_with_geo_exact.to_csv('../../../../../unT/ffunes/tweets_with_exact.csv')
tweets_with_geo_exact.to_pickle('../../../../../unT/ffunes/exact/tweets_with_exact.pkl')

# %% [markdown]
# Leemos los archivos

# %%
tweets_with_geo_bbox = pd.read_pickle('../../../../../unT/ffunes/bounding_box/tweets_with_bbox.pkl')

# %%
tweets_with_geo_bbox.shape
# Out:
# (14333531, 10)

# %% [markdown]
# Incluimos geonames

# %%
colnames = [
    "city_name",
    "latitude",
    "longitude",
    "country",
    "population"
]

geonames = pd.read_csv("../../../../../unT/ffunes/geonames/geonames_parsed.csv", usecols=colnames)

# %% [markdown]
# Para asignar una coordenada exacta, vamos a tener que utilizar los bounding box para descubrir cual de todas las ciudades con el mismo nombre es a la que se refiere el Tweet. Vamos a utilizar los centroides de los bounding box

# %%
tweets_with_geo_and_city = pd.merge(
    left=tweets_with_geo_bbox,
    right=geonames,
    how='inner',
    left_on=["place_name", "place_country"],
    right_on=["city_name", "country"],
    validate="m:m"
)

tweets_with_geo_and_city.shape
# Out:
# (11922993, 15)

# %% [markdown]
# De los 14.000.000 Tweets, 11.913.589 incluyen paises de geonames, vemos que hay una coincidencia casi del 100%. ¿Que pasa en el resto de los casos? Geonames contiene el nombre del lugar pero de otra ciudad y, al tener menor distancia, queda esa elegida, por lo que si no coincide en ciudad, se descartarian esos datos pero en la mayoria de casos, lo que ocurre es que "country" es null por el parseo y realmente en "province" se encuentra, solo aplica para casos fuera de Argentina

# %%
#tweets_with_geo_and_city.to_pickle('../../../../dosT/ffunes/tweets_with_geolocalization_geonames.pkl')

# %%
#tweets_with_geo_and_city.to_csv('../../../../../unT/ffunes/tweets_with_bbox_geonames.csv')
tweets_with_geo_and_city.to_pickle('../../../../../unT/ffunes/bounding_box/tweets_with_bbox_geonames.pkl')

# %% [markdown]
# ¿Que pasa en los casos donde no coincide geonames con twitter api?

# %%
tweets_with_bbox = pd.read_pickle('../../../../../unT/ffunes/bounding_box/tweets_with_bbox.pkl')

# %%
colnames = [
    "city_name",
    "latitude",
    "longitude",
    "country",
    "population"
]

geonames = pd.read_csv("../../../../../unT/ffunes/geonames/geonames_parsed.csv", usecols=colnames)

# %%
tweets_with_geo_and_city = pd.merge(
    left=tweets_with_bbox,
    right=geonames,
    how='inner',
    left_on=["place_name", "place_country"],
    right_on=["city_name", "country"],
    validate="m:m"
).loc[:, ["id"]]

tweets_with_geo_and_city.shape
# Out:
# (11913589, 1)

# %%
key_diff = list(set(tweets_with_bbox.id).difference(tweets_with_geo_and_city.id))

# %% [markdown]
# Lugares filtrados

# %%
for l in tweets_with_bbox[tweets_with_bbox['id'].isin(key_diff)]["place_name"].unique():
    print(l)
# Out:
# gonzález catán
# lanús oeste
# bogotá, d.c.
# general obligado
# villa soldati
# san josé del rincón
# santa fé
# putaendo
# estación central
# san fernando
# ñuñoa
# san caetano del sur
# vicente lópez
# banda
# ciudad del libertador general san martín
# almirante brown
# nuevo hamburgo
# san leopoldo
# aracajú
# jesús maria
# magdalena vieja
# lince
# puerto general san martin
# ituzaingó centro
# san pedro de los milagros
# marga-marga
# naranjito
# monte grande
# anto domingo de guzmán
# constitución
# josé carlos paz
# san juan de miraflores
# amsterdam
# कटक
# moreno
# cerro colorado
# vuelta redonda
# general pedernera
# bucarest
# eindhoven
# las condes
# chicligasta
# la victoria
# nueva iguazú
# villa san lorenzo
# wanchaq
# गाज़ियाबाद
# greater noida
# santa isabel do pará
# dr. manuel belgrano
# tacaimbó
# ibirajuba
# fighiera
# buena fe
# san miguel
# macul
# juan bautista alberdi
# south shore
# soldini
# río hondo
# vitacura
# santa maría
# daule
# 立川市
# petorca
# ...

# %%
tweets_with_bbox[tweets_with_bbox["place_name"] == "buenos aires"]
# Out:
#                            id             user_id  \
# 1461664   1176847574223003654           422921334
# 2720589   1187774592183652353           173442580
# 7466337   1142167233717841920           611758982
# 9347053   1127854896655548421          1053391308
# 12956477  1154953555096363009  910851893416611841
# 15653755  1166434906953670656            52069182
#
#                                                   full_text place_type  \
# 1461664   @MadeleineOster3 La izquierda manifiesta sus p...       city
# 2720589   Cierre de vacunación con desfile de las vaquil...       city
# 7466337   ¿Cómo es el día a día de comunidades y líderes...       city
# 9347053   Là pagine più attiva es semper@a favore enorme...       city
# 12956477  Cuando te hace creer que es liberal y se puso ...       city
# 15653755  El fracaso del Macrismo explicado en un tuit. ...       city
#
#             place_name   place_country  \
# 1461664   buenos aires            peru
# ...

# %% [markdown]
# # Creamos usuarios de Twitter-ARG-BBox

# %%
users = pd.read_sql_query('SELECT * FROM users',con=conn)

# %%
tweets_with_geo_and_city = pd.read_pickle("../../../../../unT/ffunes/bounding_box/tweets_with_bbox_geonames.pkl")

# %%
users_with_tweets = pd.merge(
    left=users,
    right=tweets_with_geo_and_city.loc[:, ["user_id", "place_type", "place_name", "place_country",
                                          "latitude", "longitude"]],
    how='inner',
    left_on=["id"],
    right_on=["user_id"],
    validate="1:m"
)

users_with_tweets.shape
# Out:
# (11922993, 19)

# %%
most_common_place_users = (users_with_tweets.groupby(["user_id", "place_name", "place_country", "latitude", "longitude"])
    .count()
    .sort_values("id", ascending=False)
    .reset_index()
    .drop_duplicates("user_id", keep='first')
    .loc[:, ["user_id", "place_name", "place_country", "latitude", "longitude"]])

# %%
users = pd.merge(
    left=users,
    right=most_common_place_users,
    how='inner',
    left_on=["id"],
    right_on=["user_id"],
    validate="1:1"
)

users.shape
# Out:
# (176130, 18)

# %%
users["unified_place"] = users["place_name"] + "," + users["place_country"]

# %%
count = users.groupby("unified_place").count().sort_values('id', ascending=False).reset_index()
count = count[count["id"] > 100]
count.shape
# Out:
# (229, 19)

# %%
users = pd.merge(
    left=users,
    right=count.loc[:, ["unified_place"]],
    how='inner',
    on='unified_place'
)

users.shape
# Out:
# (141209, 19)

# %%
del users["user_id"]

# %%
engine = create_engine('postgresql://ffunes:location8@localhost:5432/elecciones_twitter')

users.to_sql('users_location_bbox', con=engine)

# %%
users.to_pickle('../../../../../unT/ffunes/bounding_box/total_users_parsed.pkl')

# %%
users.head(3)
# Out:
#            id is_private  favourites_count  followers_count  friends_count  \
# 0  1164850459      False            1272.0            263.0         1220.0
# 1   285332838      False            1789.0           1037.0         2440.0
# 2  3044788018      False            2047.0             73.0          171.0
#
#    listed_count  statuses_count             location        support  \
# 0           1.0          4622.0               BRASIL  frentedetodos
# 1          21.0          7456.0   Rosario, Argentina           None
# 2           0.0          2053.0   Coronda, Argentina  frentedetodos
#
#   screen_name               name loc_in_argentina important place_name  \
# 0  tapa11seba  Sebastian Nardone           no_arg     False    rosario
# 1     ggoni77    Gonzalo A. Goñi              arg      True    rosario
# 2     oskr073             Oskr 🎮              arg      True    rosario
#
#   place_country   latitude  longitude      unified_place
# ...

# %% [markdown]
# Unificamos la información para manejar strings

# %%
users["location"] = users.apply(to_lower, axis=1, column="location")

# %% [markdown]
# Vemos que tenemos que parsear el campo de location

# %%
users["location"].head(10)
# Out:
# 0                         brasil
# 1    belén de escobar, argentina
# 2                      venezuela
# 3                  gijón, españa
# 4              tandil, argentina
# 5               orleans, francia
# 6     buenos aires- jose c. paz
# 7                    ramos mexia
# 8                   vigo, españa
# 9                         brasil
# Name: location, dtype: object

# %% [markdown]
# Veamos si la ubicación que incluye coincide con la mayoria de sus tweets

# %%
tweets_with_geo_and_city = pd.read_pickle("../../../../../unT/ffunes/bounding_box/tweets_with_bbox_geonames.pkl")

# %%
tweets_with_geo_and_city.columns
# Out:
# Index(['id', 'user_id', 'full_text', 'place_type', 'place_name',
#        'place_country', 'place_bounding_box', 'date', 'longitude_centroid',
#        'latitude_centroid', 'city_name', 'latitude', 'longitude', 'population',
#        'country'],
#       dtype='object')

# %%
users_with_tweets = pd.merge(
    left=users,
    right=tweets_with_geo_and_city.loc[:, ["user_id", "place_type", "place_name", "place_country",
                                          "latitude", "longitude"]],
    how='inner',
    left_on=["id"],
    right_on=["user_id"],
    validate="1:m"
)

users_with_tweets.shape
# Out:
# (9298954, 19)

# %%
most_common_place_users = (users_with_tweets.groupby(["user_id", "place_name", "place_country", "latitude", "longitude"])
    .count()
    .sort_values("id", ascending=False)
    .reset_index()
    .drop_duplicates("user_id", keep='first')
    .loc[:, ["user_id", "place_name", "place_country", "latitude", "longitude"]])

# %%
users_with_location = pd.merge(
    left=users,
    right=most_common_place_users,
    how='inner',
    left_on=["id"],
    right_on=["user_id"]
)

users_with_location.shape
# Out:
# (132013, 18)

# %% [markdown]
# Probemos asignar todos los lugares reconocidos de geonames del campo location del user

# %%
from IPython.display import clear_output

def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1

    block = int(round(bar_length * progress))

    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %%
geonames.head(1)
# Out:
#     city_name   latitude  longitude  population  country
# 0  ehl tarter  42.579521    1.65362        1052  andorra

# %%
position = 0
total = users_with_location.shape[0]
cities = geonames["city_name"].values
countries = geonames["country"].unique()

def check_all_places(places, country):
    total_not_detected = 0
    total_exact = 0
    
    for place in places:
        ocurrences = np.where(cities == place)[0]
        
        if len(ocurrences) == 0:
            total_not_detected += 1
            continue
        
        for index in ocurrences:
            #country_names = countries.loc[
            #                    countries["Code"] == geonames_splitted_names["country code"][index], ["Name"]
            #                ]
            country_name = geonames["country"][index]
            
            #if country_names.empty:
            #    continue
                
            '''country_detected = False
                
            for country_iso in country_names["Name"].values:
                if country == country_iso:
                    country_detected = True
                    total_exact += 1
                    break
            
            if country_detected:
                break'''
            if country_name == country:
                total_exact += 1
                break
    
    if total_exact == 1:
        return 'Ubicacion exacta'
    elif (total_not_detected == len(places)) | (total_exact == 0):
        return 'Ubicacion es un pais'
    return 'Ubicacion ambigua'

def es_univoco(value):
    global position;
    global total;
    global cities;
    
    location = value.replace("-", ",")
    location = location.replace("/", ",")
    all_words = location.split(',')
    all_words = [word.strip() for word in all_words]
    
    update_progress(position / total)
    position += 1
    
    if len(all_words) == 1:
        place = all_words[0]
        if place in countries:
            return 'Ubicacion es un pais'  
        
        ocurrences = np.where(cities == place)[0]
        
        if len(ocurrences) == 0:
            return 'No existe ubicacion'
        elif len(ocurrences) == 1:
            return 'Ubicacion exacta'
    
        return 'Ubicacion ambigua'
    
    #Veamos si alguna palabra es un País    
    for word in all_words:    
        if word in countries:
            all_words.remove(word)
            return check_all_places(all_words, word)
    
    counter = 0
        
    for word in all_words:    
        ocurrences = np.where(cities == word)[0]

        if len(ocurrences) == 0:
            counter += 1
        
    if counter == len(all_words):
        return 'No existe ubicacion'
        
    return 'Ubicacion ambigua'

# %%
users_with_location["detected_location"] = users_with_location['location'].apply(es_univoco)
# Out:
# Progress: [####################] 100.0%

# %%
users_with_location.shape
# Out:
# (132013, 18)

# %%
users_with_location["detected_location"].value_counts()
# Out:
# Ubicacion exacta        54049
# Ubicacion ambigua       30993
# No existe ubicacion     25482
# Ubicacion es un pais    21489
# Name: detected_location, dtype: int64

# %%
print(users_with_location["detected_location"].value_counts()[0]/users_with_location.shape[0])
print(users_with_location["detected_location"].value_counts()[1]/users_with_location.shape[0])
print(users_with_location["detected_location"].value_counts()[2]/users_with_location.shape[0])
print(users_with_location["detected_location"].value_counts()[3]/users_with_location.shape[0])
# Out:
# 0.409421799368244
# 0.23477233302780787
# 0.19302644436532765
# 0.16277942323862044

# %%
position = 0
total = users_with_location.shape[0]
cities = geonames["city_name"].values
countries = geonames["country"].unique()

def check_all_places_determine(places, country):
    total_not_detected = 0
    total_exact = 0
    index_exact = 0
    places_determined = []
    
    for place in places:
        ocurrences = np.where(cities == place)[0]
        
        if len(ocurrences) == 0:
            total_not_detected += 1
            continue
        
        for index in ocurrences:
            '''country_names = countries.loc[
                                countries["Code"] == geonames_splitted_names["country code"][index], ["Name"]
                            ]
            
            if country_names.empty:
                continue
                
            country_detected = False'''
            country_name = geonames["country"][index]
            
            if country == country_name:
                total_exact += 1
                places_determined.append({
                    "place": place,
                    "population":  geonames["population"][index],
                    "latitude":  geonames["latitude"][index],
                    "longitude":  geonames["longitude"][index]                        
                })
                break               
            '''for country_iso in country_names["Name"].values:
                if country == country_iso:
                    total_exact += 1
                    country_detected = True
                    places_determined.append({
                        "place": place,
                        "population":  geonames_splitted_names["population"][index],
                        "latitude":  geonames_splitted_names["latitude"][index],
                        "longitude":  geonames_splitted_names["longitude"][index]                        
                    })
                    break
            
            if country_detected:
                break'''
    
    if total_exact == 1:
        return [places_determined, country]
    elif (total_not_detected == len(places)) | (total_exact == 0):
        return [None, country]
    
    return [places_determined, country]

def determine_place(value):
    global position;
    global total;
    global cities;
    
    location = value.replace("-", ",")
    location = location.replace("/", ",")
    all_words = location.split(',')
    all_words = [word.strip() for word in all_words]
        
    update_progress(position / total)
    position += 1
    
    if len(all_words) == 1:
        place = all_words[0]        
        if place in countries:
            return [None, place]
        
        ocurrences = np.where(cities == place)[0]
        
        #print(place)
        
        if len(ocurrences) == 0:
            return [None, None]
        elif len(ocurrences) == 1:
            return [[{
                "place": place,
                "population":  geonames["population"][ocurrences[0]],
                "latitude":  geonames["latitude"][ocurrences[0]],
                "longitude":  geonames["longitude"][ocurrences[0]]
            }], None]
        
        places_determined = []
        
        for index in ocurrences:
            places_determined.append({
                "place": place,
                "population":  geonames["population"][index],
                "latitude":  geonames["latitude"][index],
                "longitude":  geonames["longitude"][index]                        
            })
    
        return [places_determined, None]#'Ubicacion ambigua'
    
    #Veamos si alguna palabra es un País    
    for word in all_words:    
        if word in countries:
            all_words.remove(word)
            return check_all_places_determine(all_words, word)

    counter = 0
    places_determined = []
        
    for word in all_words:    
        ocurrences = np.where(cities == word)[0]

        if len(ocurrences) == 0:
            counter += 1
        else:
            for index in ocurrences:
                places_determined.append({
                    "place": word,
                    "population":  geonames["population"][index],
                    "latitude":  geonames["latitude"][index],
                    "longitude":  geonames["longitude"][index]                        
                })
        
    if counter == len(all_words):
        return [None, None]#'No existe ubicacion'
        
    return [places_determined, None]#'Ubicacion ambigua'

# %%
geonames.shape
# Out:
# (1416909, 5)

# %%
users_with_location["profile_city"], users_with_location["profile_country"] = zip(*users_with_location['location'].apply(determine_place))
# Out:
# Progress: [####################] 100.0%
# /var/home/ffunes/.local/share/virtualenvs/python_env--wEOliWe/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# De los usuarios que se pudo obtener el pais, coincide un 88% con la mayoria de sus tweets!

# %%
total = users_with_location.dropna(subset=["profile_country"]).shape[0]

a = users_with_location.dropna(subset=["profile_country"])
subtotal = a.loc[a["profile_country"] == a["place_country"], :].shape[0]

subtotal / total
# Out:
# 0.8822297268413628

# %% [markdown]
# De los usuarios con ubicacion exacta, coincide un 90% con la mayoria de sus tweets!

# %%
u = users_with_location.loc[users_with_location["detected_location"] == "Ubicacion exacta", :]
total = u.dropna(subset=["profile_country"]).shape[0]

a = u.dropna(subset=["profile_country"])
subtotal = a.loc[a["profile_country"] == a["place_country"], :].shape[0]

subtotal / total
# Out:
# 0.9044377206253151

# %% [markdown]
# Veamos coincidencia para las ubicaciones exactas con las ciudades

# %%
def veracity(row):
    if row['profile_city'][0]['place'] == row['place_name']:
        return True
    
    return False

u = users_with_location.loc[users_with_location["detected_location"] == "Ubicacion exacta", :]
total = u.shape[0]

u["veracity"] = u.apply(veracity, axis=1)
subtotal = u.loc[u["veracity"] == True, :].shape[0]
subtotal / total
# Out:
# <ipython-input-154-c5e2ab68e518>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   u["veracity"] = u.apply(veracity, axis=1)
# 0.5202501433884068

# %%
users_with_location.to_pickle('../../../../../unT/ffunes/bounding_box/users_location_parsed.pkl')

# %% [markdown]
# Update: Agreguemos los usuarios sin ubicacion también

# %%
users_no_location = pd.read_sql_query('SELECT * FROM users WHERE location IS NULL',con=conn)

# %%
users_no_location.shape
# Out:
# (956989, 13)

# %%
users_with_tweets = pd.merge(
    left=users_no_location,
    right=tweets_with_geo_and_city.loc[:, ["user_id", "place_type", "place_name", "place_country",
                                          "latitude", "longitude"]],
    how='inner',
    left_on=["id"],
    right_on=["user_id"],
    validate="1:m"
)

users_with_tweets.shape
# Out:
# (2624039, 19)

# %%
users_with_location.columns
# Out:
# Index(['id', 'is_private', 'favourites_count', 'followers_count',
#        'friends_count', 'listed_count', 'statuses_count', 'location',
#        'support', 'screen_name', 'name', 'loc_in_argentina', 'important',
#        'user_id', 'place_name', 'place_country', 'latitude', 'longitude'],
#       dtype='object')

# %%
most_common_place_users = (users_with_tweets.groupby(["user_id", "place_name", "place_country", "latitude", "longitude"])
    .count()
    .sort_values("id", ascending=False)
    .reset_index()
    .drop_duplicates("user_id", keep='first')
    .loc[:, ["user_id", "place_name", "place_country", "latitude", "longitude"]])

# %%
users_with_no_location = pd.merge(
    left=users_no_location,
    right=most_common_place_users,
    how='inner',
    left_on=["id"],
    right_on=["user_id"]
)

users_with_no_location.shape
# Out:
# (44117, 18)

# %%
del users_with_no_location["user_id"]

# %%
users_with_no_location.head(2)
# Out:
#           id is_private  favourites_count  followers_count  friends_count  \
# 0  107451528       None               NaN              NaN            NaN
# 1  188569827       True               NaN              NaN            NaN
#
#    listed_count  statuses_count location            support    screen_name  \
# 0           NaN             NaN     None               None      RTFMCelia
# 1           NaN             NaN     None  juntosporelcambio  massonefranco
#
#              name loc_in_argentina important place_name place_country  \
# 0  💚Celia Cintas🧡             None      None    nairobi         kenia
# 1          franco             None      True      luján     argentina
#
#     latitude  longitude
# 0  -1.283330  36.816669
# 1 -34.570278 -59.105000

# %%
users_with_no_location["detected_location"] = "No existe ubicacion"
users_with_no_location["profile_city"] = None
users_with_no_location["profile_country"] = None

# %%
total_users = pd.concat([users_with_location, users_with_no_location])

# %%
total_users.to_pickle('../../../../../unT/ffunes/bounding_box/total_users_parsed.pkl')

# %% [markdown]
# Analizemos distancias de Tweets con campo location

# %%
users_with_location = pd.read_pickle('../../../../../unT/ffunes/bounding_box/users_location_parsed.pkl')

# %%
users_with_exact_location = users_with_location.loc[users_with_location["detected_location"] == "Ubicacion exacta", :]
users_with_exact_location.shape
# Out:
# (54049, 20)

# %%
from math import radians, sin, cos, atan2, sqrt

def haversine_distance(lat1, lon1, lat2, lon2):
    radius = 6371 # km

    dlat = radians(lat2-lat1)
    dlon = radians(lon2-lon1)
    a = sin(dlat/2) * sin(dlat/2) + cos(radians(lat1)) \
        * cos(radians(lat2)) * sin(dlon/2) * sin(dlon/2)
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    d = radius * c

    return d

# %%
def determine_distance(row):
    profile_lat = row['profile_city'][0]['latitude']
    profile_lon = row['profile_city'][0]['longitude']
    tweet_lat = row['latitude']
    tweet_long = row['longitude']
    
    return haversine_distance(profile_lat, profile_lon, tweet_lat, tweet_long)

# %%
users_with_exact_location["distance_dif_in_km"] = users_with_exact_location.apply(determine_distance, axis=1)
# Out:
# <ipython-input-6-1b4175f9dafe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_exact_location["distance_dif_in_km"] = users_with_exact_location.apply(determine_distance, axis=1)

# %%
users_with_exact_location.shape
# Out:
# (54049, 21)

# %%
users_with_exact_location.loc[users_with_exact_location["distance_dif_in_km"] == 0, :].shape
# Out:
# (33494, 21)

# %%
users_with_exact_location.loc[users_with_exact_location["distance_dif_in_km"] > 0].shape
# Out:
# (20555, 21)

# %%
plt.figure(figsize=(20,10)) 
#plt.hist(users_with_exact_location.loc[users_with_exact_location["distance_dif_in_km"] > 0]['distance_dif_in_km'], bins=np.logspace(-1, 5, 20))
plt.hist(users_with_exact_location['distance_dif_in_km'], bins=np.logspace(-1, 5, 20))
plt.xlabel("Kilometros", fontsize=16)
plt.ylabel("Cantidad de usuarios", fontsize=16)
plt.title("Histograma de distancias en Km de ubicación en mayoría de Tweets vs perfil del usuario", fontsize=18)
#plt.xlim(0, 4000)
#sum(users_with_exact_location['distance_dif_in_km']<=1)
plt.xscale('symlog')
plt.show()

plt.figure(figsize=(20,10)) 
plt.hist(users_with_exact_location['distance_dif_in_km'], bins=200)
plt.xlabel("Kilometros [log]", fontsize=16)
plt.ylabel("Cantidad de usuarios", fontsize=16)
plt.title("Histograma de distancias en Km de ubicación en mayoría de Tweets vs perfil del usuario", fontsize=18)
plt.xlim(0, 1200)
plt.show()

# %%
users_with_exact_location[users_with_exact_location["distance_dif_in_km"] <= 40.0].shape[0] / users_with_exact_location.shape[0]
# Out:
# 0.7174785842476271

# %%
from math import log
f, ax = plt.subplots(figsize=(10, 10))

sns.ecdfplot(
    data=users_with_exact_location["distance_dif_in_km"],
    stat="proportion",
    #log_scale=True,
    #complementary=True,
    ax=ax,
    linewidth=4
)

mark_at = 10.0

perc = users_with_exact_location[users_with_exact_location["distance_dif_in_km"] < mark_at].shape[0] / users_with_exact_location.shape[0]

ax.set_ylim(0, 1.05)
ax.set_xlim(0, 15000)
ax.set_xscale('symlog')
#ax.set_title("Distancia entre la ciudad de la mayoría de los Tweets y la del Perfil", fontsize=20, fontweight='bold', pad=20)
ax.set_xlabel("Distancia (km)", fontsize=22, labelpad=20)
ax.set_ylabel("Proporción de usuarios", fontsize=22, labelpad=20)
ax.set_yticks(np.arange(0,1.1,0.1))
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))

ax.plot([0, mark_at], [perc, perc], color='green', linestyle='dashed', linewidth=2)
ax.plot([mark_at, mark_at], [0, perc], color='green', linestyle='dashed', linewidth=2)
ax.plot([mark_at], [perc], color='green', marker='o', markersize=12)

ax.annotate(
    '({}, {:.2f})'.format(mark_at, perc),
    (mark_at, perc + 0.07),
    ha='center',
    fontsize=18,
    color="green",
    weight='bold'
)

plt.gca().spines['bottom'].set_color('#888888')
plt.gca().spines['top'].set_color('#888888') 
plt.gca().spines['right'].set_color('#888888')
plt.gca().spines['left'].set_color('#888888')

plt.gca().set_xlim(left=1)
plt.gca().set_ylim(top=1)

plt.setp(ax.get_xticklabels(), fontsize=16)
plt.setp(ax.get_yticklabels(), fontsize=16)
plt.grid()
plt.show()

#ax.axvline(x=mark_at, ymax=perc-0.03, color='green')
#ax.axhline(y=perc-0.03, xmax=log(40.0)/log(10380), color='green')
f.savefig(figuresPath + 'profile/ecdf_distance_prof_maj_tweet2.pdf', bbox_inches = 'tight')

#f.savefig("../../results/plots/creacion_set_validacion/dif_distance_city_majority_tweets_and_profile.pdf", bbox_inches='tight')

# %% [markdown]
# Ahora vamos con algo más logico, que coincida el pais del perfil con el de la mayoria de los tweets

# %%
f, ax = plt.subplots(figsize=(16, 9))

sns.set_theme()

sns.ecdfplot(
    data=users_with_exact_location.loc
        [users_with_exact_location["place_country"] == users_with_exact_location["profile_country"]]['distance_dif_in_km'],
    stat="proportion",
    #log_scale=True,
    ax=ax
)

ax.set_ylim(0, 1.1)
ax.set_xlim(0, 5000)
ax.set_xscale('symlog')
ax.set_title("Distancia entre la ciudad de la mayoría de los Tweets y la del Perfil con coincidencia a nivel País", fontsize=20, fontweight='bold', pad=20)
ax.set_xlabel("Diferencia en kilómetros", fontsize=18, labelpad=20)
ax.set_ylabel("Proporción de usuarios", fontsize=18, labelpad=20)
ax.set_yticks(np.arange(0,1.1,0.1))
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))

f.savefig("../../results/plots/creacion_set_validacion/dif_distance_country_majority_tweets_and_profile.pdf", bbox_inches='tight')

# %% [markdown]
# Veamos casos donde la ubicacion es ambigua

# %%
def get_closest_place_to_tweet(row):
    minor_dist = -1

    for place in row["profile_city"]:
        profile_lat = place['latitude']
        profile_lon = place['longitude']
        tweet_lat = row['latitude']
        tweet_long = row['longitude']

        new_dist = haversine_distance(profile_lat, profile_lon, tweet_lat, tweet_long)

        if (new_dist < minor_dist) | (minor_dist == -1):
            minor_dist = new_dist
    
    return minor_dist

# %%
users_with_ambiguous_location = users_with_location.loc[users_with_location["detected_location"] == "Ubicacion ambigua", :]
users_with_ambiguous_location.shape
# Out:
# (30805, 21)

# %%
users_with_ambiguous_location["distance_dif_in_km"] = users_with_ambiguous_location.apply(determine_distance, axis=1)
# Out:
# <ipython-input-123-945c613f4369>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_ambiguous_location["distance_dif_in_km"] = users_with_ambiguous_location.apply(determine_distance, axis=1)

# %%
users_with_ambiguous_location.loc[users_with_ambiguous_location["distance_dif_in_km"] > 0, ["location", "profile_city", "profile_country", "place_name", "place_country", "distance_dif_in_km"]]
# Out:
#                             location  \
# 46                     san francisco
# 62      minas brasil, belo horizonte
# 168         porto seguro-ba; brasil
# 175                             caba
# 193            barquisimeto-edo lara
# ...                              ...
# 131788                  buenos aires
# 131824                   mexico city
# 131827              ciudad de mexico
# 131838        san francisco, córdoba
# 131847    tres arroyos, (bs as) arg.
#
#                                              profile_city profile_country  \
# 46      [{'longitude': -66.1253890991211, 'population'...            None
# 62      [{'longitude': -36.82889175415039, 'population...            None
# 168     [{'longitude': -39.064720153808594, 'populatio...            None
# 175     [{'longitude': 76.12647247314453, 'population'...            None
# 193     [{'longitude': -69.3570327758789, 'population'...            None
# ...

# %%
f, ax = plt.subplots(figsize=(16, 9))

sns.set_theme()

sns.ecdfplot(
    data=users_with_ambiguous_location["distance_dif_in_km"],
    stat="proportion",
    #log_scale=True,
    ax=ax
)

ax.set_ylim(0, 1.1)
ax.set_xlim(0, 20000)
ax.set_xscale('symlog')
ax.set_title("Distancia entre la ciudad de la mayoría de los Tweets y la del Perfil con ubicación ambigua", fontsize=20, fontweight='bold', pad=20)
ax.set_xlabel("Diferencia en kilómetros", fontsize=18, labelpad=20)
ax.set_ylabel("Proporción de usuarios", fontsize=18, labelpad=20)
ax.set_yticks(np.arange(0,1.1,0.1))
ax.xaxis.set_tick_params(labelsize=16)
ax.yaxis.set_tick_params(labelsize=16)
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))

# %%
plt.figure(figsize=(20,10)) 
plt.hist(users_with_ambiguous_location['distance_dif_in_km'], bins=np.logspace(0, 5, 20))
plt.xlabel("Kilometros [log]", fontsize=16)
plt.ylabel("Cantidad de usuarios", fontsize=16)
plt.title("Histograma de distancias en Km de ubicación en mayoría de Tweets vs perfil del usuario", fontsize=18)
#plt.xlim(0, 4000)
plt.figsize=(10,8)
plt.xscale('log')
plt.show()

plt.figure(figsize=(20,10)) 
plt.hist(users_with_ambiguous_location['distance_dif_in_km'], bins=200)
plt.xlabel("Kilometros", fontsize=16)
plt.ylabel("Cantidad de usuarios", fontsize=16)
plt.title("Histograma de distancias en Km de ubicación en mayoría de Tweets vs perfil del usuario", fontsize=18)
plt.xlim(0, 2500)
plt.figsize=(10,8)
plt.show()

# %% [markdown]
# # Armado de usuarios de Twitter-ARG-Exact

# %%
tweets_with_geo_exact = pd.read_pickle('../../../../../unT/ffunes/exact/tweets_with_exact.pkl')

# %%
tweets_with_geo_exact.dtypes
# Out:
# user_id                   int64
# id                        int64
# full_text                object
# place_type               object
# place_name               object
# place_country            object
# coordinates            geometry
# date             datetime64[ns]
# latitude                float64
# longitude               float64
# dtype: object

# %%
tweets_with_geo_exact.shape
# Out:
# (1022033, 10)

# %%
colnames = [
    "asciiname",
    "latitude",
    "longitude",
    "Name",
    "population"
]

geonames = pd.read_csv("../../../../../unT/ffunes/geonames.csv", usecols=colnames)

# %%
geonames = geonames.rename(columns={"asciiname": "city_name", "Name": "country"})
geonames.head(2)
# Out:
#    city_name  latitude  longitude  population  country
# 0     soldeu  42.57688    1.66769         602  andorra
# 1  el tarter  42.57952    1.65362        1052  andorra

# %%
sample = tweets_with_geo_exact.sample(1)
sample
# Out:
#                          id   user_id  \
# 946067  1131763116826595328  20113972
#
#                                                 full_text place_type  \
# 946067  "If a man needs an elaborate tombstone in orde...       city
#
#                              place_name place_country  \
# 946067  ciudad autónoma de buenos aires     argentina
#
#                         coordinates                date   latitude  longitude
# 946067  POINT (-58.39306 -34.58806) 2019-05-24 03:25:28 -34.588056 -58.393056

# %%
tree = BallTree(geonames[["latitude", "longitude"]])              
#dist, ind = tree.query(tweets_with_geo_exact.sample(1)[["latitude", "longitude"]], k=3)

# %%
dist, ind = tree.query(sample[["latitude", "longitude"]], k=3)

# %%
ind[0]
# Out:
# array([1159, 2061, 1361])

# %%
geonames.iloc[ind[0]]
# Out:
#          city_name  latitude  longitude  population    country
# 1159        retiro -34.58333  -58.38333       38635  argentina
# 2061     balvanera -34.61032  -58.39766      152198  argentina
# 1361  buenos aires -34.61315  -58.37723    13076300  argentina

# %%
dist
# Out:
# array([[0.00988778, 0.37244554, 0.43283538]])

# %%
tweets_with_geo_exact = tweets_with_geo_exact.loc[tweets_with_geo_exact["place_type"] == "city", :]

# %%
users = pd.read_sql_query('SELECT * FROM users',con=conn)

# %%
users_with_tweets = pd.merge(
    left=users,
    right=tweets_with_geo_exact.loc[:, ["user_id", "place_type", "place_name", "place_country",
                                          "latitude", "longitude"]],
    how='inner',
    left_on=["id"],
    right_on=["user_id"],
    validate="1:m"
)

users_with_tweets.shape
# Out:
# (856978, 19)

# %%
most_common_place_users = (users_with_tweets.groupby(["user_id", "place_name", "place_country"])
    .count()
    .sort_values("id", ascending=False)
    .reset_index()
    .drop_duplicates("user_id", keep='first')
    .loc[:, ["user_id", "place_name", "place_country"]])

# %%
most_common_place_users = pd.merge(
    most_common_place_users,
    users_with_tweets.loc[:, ["user_id", "place_name", "place_country", "latitude", "longitude"]],
    how='inner',
    left_on=['user_id', 'place_name', 'place_country'],
    right_on=['user_id', 'place_name', 'place_country'],
    validate="1:m"
)

# %%
most_common_place_users = most_common_place_users.sample(frac=1).drop_duplicates("user_id") #Shuffle

# %%
users_with_coords = pd.merge(
    users,
    most_common_place_users,
    how='inner',
    left_on='id',
    right_on='user_id',
    validate="1:1"
)

del users_with_coords["user_id"]
users_with_coords.head(2)
# Out:
#           id is_private  favourites_count  followers_count  friends_count  \
# 0  188569827       True               NaN              NaN            NaN
# 1   31945136      False             103.0            183.0          778.0
#
#    listed_count  statuses_count           location            support  \
# 0           NaN             NaN               None  juntosporelcambio
# 1           1.0          1533.0  Santiago de Chile               None
#
#       screen_name                 name loc_in_argentina important  \
# 0   massonefranco               franco             None      True
# 1  marcegonzalezg  Marcela González G.           no_arg     False
#
#                      place_name place_country   latitude  longitude
# 0                  villa gesell     argentina -37.256524 -56.973183
# 1  puerto presidente stroessner      paraguay -25.510300 -54.671200

# %%
users_with_coords.shape
# Out:
# (59067, 17)

# %%
users_with_coords.to_pickle('../../../../../unT/ffunes/exact/users_exact_coords.pkl')

# %% [markdown]
# # Un analisis simple de KD-Trees

# %%
users_with_coords = pd.read_pickle('../../../../../unT/ffunes/exact/users_exact_coords.pkl')
users_with_coords.shape
# Out:
# (37146, 21)

# %%
users_with_coords["unified_place"] = users_with_coords["place_name"] + "," + users_with_coords["place_country"]

# %%
c = users_with_coords.groupby("unified_place").count().sort_values('id', ascending=False).reset_index()
c = c[c["id"] > 100]
c.shape
# Out:
# (95, 21)

# %%
users_with_coords = pd.merge(
    left=c.loc[:, "unified_place"],
    right=users_with_coords,
    how='inner'
)

# %%
users_with_coords.shape
# Out:
# (37146, 21)

# %%
engine = create_engine('postgresql://ffunes:location8@localhost:5432/elecciones_twitter')

# %%
users_with_coords.to_sql('users_location_exact', con=engine, if_exists='replace')

# %%
tweets_with_geo_exact.shape
# Out:
# (856978, 10)

# %%
tweets_with_geo_exact = pd.merge(
    left=users_with_coords.loc[:, ["id"]].rename(columns={"id": "user_id"}),
    right=tweets_with_geo_exact,
    how='inner',
    left_on='user_id',
    right_on='user_id',
    validate='1:m'
)

tweets_with_geo_exact.shape
# Out:
# (548615, 10)

# %%
users_with_coords.to_pickle('../../../../../unT/ffunes/exact/users_exact_coords.pkl')

# %%
tweets_with_geo_exact.to_pickle('../../../../../unT/ffunes/exact/tweets_with_exact.pkl')

# %%
users_with_coords = pd.read_pickle('../../../../../unT/ffunes/exact/users_exact_coords.pkl')
users_with_coords.shape
# Out:
# (37146, 21)

# %%
d = users_with_coords.groupby("place_country").count().sort_values('id', ascending=False).reset_index()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
rects = sns.barplot(x="id", y="place_country", data=d, ax=ax)
ax.set_title("Distribución de usuarios por país", fontsize=34, pad=20)
ax.set_xlabel("#Usuarios [log]",fontsize=26, labelpad=28)
ax.set_ylabel("",fontsize=26)
ax.tick_params(axis='y', which='both', labelsize=24)
ax.tick_params(axis='x', which='both', labelsize=24)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))
ax.set_xticks(np.logspace(1.0, 5.0, num=10))


#plt.xticks(np.arange(0, np.max(dist_profs["id"]) + 5000, 5000.0))

for p in rects.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{0:.1%}'.format(width/np.sum(d["unified_place"])),
        (x + width / 1.5, y + height / 1.5),
        ha='center',
        fontsize=22,
        color="black",
        weight='bold'
    )
    
plt.savefig(figuresPath + 'preanalisis/distribution_exact_country.pdf', bbox_inches = 'tight')
plt.show()

# %%
d = users_with_coords.loc[users_with_coords["place_country"]=="argentina", :].groupby("place_name").count().sort_values('id', ascending=False).reset_index()

# %%
fig, ax = plt.subplots(figsize=(20, 30))
rects = sns.barplot(x="id", y="place_name", data=d, ax=ax)
ax.set_title("Distribución de usuarios por ciudad", fontsize=34, pad=20)
ax.set_xlabel("#Usuarios [log]",fontsize=26, labelpad=28)
ax.set_ylabel("",fontsize=26)
ax.tick_params(axis='y', which='both', labelsize=24)
ax.tick_params(axis='x', which='both', labelsize=24)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))
ax.set_xticks(np.logspace(1.0, 4.0, num=10))


#plt.xticks(np.arange(0, np.max(dist_profs["id"]) + 5000, 5000.0))
    
#plt.savefig(figuresPath + 'preanalisis/distribution_exact_city.pdf', bbox_inches = 'tight')
plt.show()

# %%
def create_points(row):
    return Point(row["longitude"], row["latitude"])

points = users_with_coords[["latitude", "longitude"]].apply(create_points, axis=1)
points_df = gpd.GeoDataFrame({"points": points}, geometry='points')

# %%
world = gpd.read_file(
    gpd.datasets.get_path('naturalearth_lowres')
)

# %%
fig, ax = plt.subplots(figsize=(20, 20))

#ax.set_aspect('equal')
ax.set_title("Ubicación de usuarios con coordenadas específicas", fontsize=34, pad=20)

world.plot(ax=ax, color='white', edgecolor='black')

#region_df.plot(ax=ax, cmap="tab20b", alpha=0.3, linewidth=2, linestyle='-', edgecolor="black")
points_df.plot(ax=ax, marker='o', markersize=120, cmap="tab20b", alpha=1.0)

ax.set_xlim(-130, 80)
ax.set_ylim(-65, 60)

plt.savefig(figuresPath + 'preanalisis/distribution_world_exact.pdf', bbox_inches = 'tight')

plt.show();

# %%
users_with_location = pd.read_pickle('../../../../../unT/ffunes/bounding_box/users_location_parsed.pkl')

# %%
users_with_location["detected_city"] = users_with_location["place_name"] + "," + users_with_location["place_country"]

# %%
users_with_location.loc[:, ["name", "location", "detected_city"]].sample(frac=0.3).head(10)
# Out:
#                          name                        location  \
# 36963           Gustavo Rojas     madrid, comunidad de madrid
# 2830                 celinita         buenos aires, argentina
# 59581             @ser_dgauna  ciudad autónoma de buenos aire
# 7052   Ivan Oscar Dondo Zurko           corrientes, argentina
# 93554          Carlos Cabrera                 toronto, canada
# 52487               Barrio 88             santa fe, argentina
# 25303           Juli Guallama         estudiantes de la plata
# 93058    JuanSebastianQuiceno                         pereira
# 94605              Luiz Paulo                         aracaju
# 1612                  Nicolas        mar del plata, argentina
#
#                                    detected_city
# 36963                              madrid,españa
# 2830   ciudad autónoma de buenos aires,argentina
# 59581                       avellaneda,argentina
# 7052                        corrientes,argentina
# ...

# %%
users_with_location[users_with_location["detected_location"] == "Ubicacion exacta"].shape
# Out:
# (54049, 21)

# %%
dist_profs = users_with_location.groupby("detected_location").count().sort_values("id", ascending=False).reset_index()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
rects = sns.barplot(x="id", y="detected_location", data=dist_profs, ax=ax)
ax.set_title("Distribución de ubicaciónes en perfiles", fontsize=34, pad=20)
ax.set_xlabel("#Usuarios",fontsize=26, labelpad=28)
ax.set_ylabel("",fontsize=26)
ax.tick_params(axis='y', which='both', labelsize=24)
ax.tick_params(axis='x', which='both', labelsize=24)

plt.xticks(np.arange(0, np.max(dist_profs["id"]) + 5000, 5000.0))

for p in rects.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{0:.1%}'.format(width/users_with_location.shape[0]),
        (x + width / 2.0, y + height / 1.8),
        ha='center',
        fontsize=28,
        color="white",
        weight='bold'
    )
    
plt.savefig(figuresPath + 'profile/profiles_loc_dist.pdf', bbox_inches = 'tight')
plt.show()

# %%
bbox_users = pd.read_pickle('../../../../../unT/ffunes/bounding_box/total_users_parsed.pkl')

# %%
bbox_users["unified_place"] = bbox_users["place_name"] + "," + bbox_users["place_country"]

# %%
bbox_users["unified_place"].nunique()
# Out:
# 229

# %%
c = bbox_users.groupby("unified_place").count().sort_values('id', ascending=False).reset_index()
c = c[c["id"] > 100]
c.shape
# Out:
# (229, 18)

# %%
c = pd.merge(
    left=c.loc[:, "unified_place"],
    right=bbox_users,
    how='inner'
)

# %%
c.shape
# Out:
# (141209, 18)

# %%
d = c.groupby("place_country").count().sort_values('id', ascending=False).reset_index()
d.head(1)
# Out:
#   place_country  unified_place      id  is_private  favourites_count  \
# 0     argentina         102567  102567      102567             97958
#
#    followers_count  friends_count  listed_count  statuses_count  location  \
# 0            97958          97958         97958           97958     74541
#
#    support  screen_name    name  loc_in_argentina  important  place_name  \
# 0    86637       101716  101716             74541     102567      102567
#
#    latitude  longitude
# 0    102567     102567

# %%
fig, ax = plt.subplots(figsize=(20, 20))
rects = sns.barplot(x="id", y="place_country", data=d, ax=ax)
ax.set_title("Distribución de usuarios por país", fontsize=34, pad=20)
ax.set_xlabel("#Usuarios [log]",fontsize=26, labelpad=28)
ax.set_ylabel("",fontsize=26)
ax.tick_params(axis='y', which='both', labelsize=24)
ax.tick_params(axis='x', which='both', labelsize=24)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter("%d"))
ax.set_xticks(np.logspace(1.0, 5.0, num=10))


#plt.xticks(np.arange(0, np.max(dist_profs["id"]) + 5000, 5000.0))

for p in rects.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(
        '{0:.1%}'.format(width/np.sum(d["unified_place"])),
        (x + width / 1.5, y + height / 1.5),
        ha='center',
        fontsize=22,
        color="black",
        weight='bold'
    )
    
plt.savefig(figuresPath + 'preanalisis/distribution_bbox_country.pdf', bbox_inches = 'tight')
plt.show()
