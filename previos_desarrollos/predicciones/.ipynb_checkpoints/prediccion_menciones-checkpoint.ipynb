# %%
import pandas as pd
import psycopg2
import pandas.io.sql as psql
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, cross_val_predict, cross_validate
from sklearn.model_selection import train_test_split
from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.metrics import classification_report, make_scorer
from sklearn.metrics import accuracy_score
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import balanced_accuracy_score, accuracy_score, roc_auc_score
from sklearn.metrics import plot_confusion_matrix, confusion_matrix
from collections import OrderedDict
from sklearn.manifold import TSNE
from sklearn.svm import SVC
from sklearn.preprocessing import scale
from sklearn.decomposition import TruncatedSVD
import matplotlib.cm as cm
import time
import scipy.sparse
import seaborn as sns
import lightgbm as lgb
import category_encoders as ce
import re
from imblearn.ensemble import BalancedRandomForestClassifier

dosTPath = "../../../../../dosT/ffunes/"

# %matplotlib inline

sns.set_theme()

# %% [markdown]
# # Oslom parse

# %%
def extract_oslom(filename):
    """Funcion que extrae las comunidades detectadas por OSLOM a las que pertence un vertice de la red."""
    clusters = {}
    hashtag_clusters = {}
    data = []
    with open(filename) as f:
        cluster = ""
        for line in f:
            m = re.search("^#module\s([0-9]+).*", line)
            #print line
            if (m is not None):
                cluster = int(m.group(1))
            else:
                l = line.replace('\n', ' ').strip().split(" ")
                l = list(map(int, l))
                clusters[cluster] = l
                for i in l:
                    if not i in hashtag_clusters:
                        hashtag_clusters[i] = set()
                    hashtag_clusters[i].add(cluster)
                    data.append([i, cluster])
    return pd.DataFrame(data=data, columns=["id", "cluster"]), hashtag_clusters

# %% [markdown]
# # Función para calcular distancias entre datos predecidos y reales

# %%
geonames = pd.read_pickle(dosTPath + "geonames_parsed.pkl")

from math import radians, sin, cos, atan2, sqrt

def haversine_distance(lat1, lon1, lat2, lon2):
    radius = 6371 # km

    dlat = radians(lat2-lat1)
    dlon = radians(lon2-lon1)
    a = sin(dlat/2) * sin(dlat/2) + cos(radians(lat1)) \
        * cos(radians(lat2)) * sin(dlon/2) * sin(dlon/2)
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    d = radius * c

    return d

def determine_distance(row):
    predicted_lat = row['predicted_lat']
    predicted_lon = row['predicted_lon']
    real_lat = row['real_lat']
    real_long = row['real_lon']
    
    return haversine_distance(predicted_lat, predicted_lon, real_lat, real_long)

def get_difference_distance(predicted_place, real_place):
    df_prediction = pd.DataFrame({
        'predicted_place': predicted_place,
        'real_place': real_place
    }, dtype=float)
        
    df_prediction[['predicted_cities','predicted_countries']] = df_prediction.predicted_place.str.split(',', expand=True) 
    df_prediction[['real_cities','real_countries']] = df_prediction.real_place.str.split(',', expand=True) 
    
    del df_prediction['predicted_place']
    del df_prediction['real_place']
    
    df_prediction = pd.merge(
        left=df_prediction,
        right=geonames.loc[:,['alternatenames', 'country', 'latitude', 'longitude']],
        how='left',
        left_on=['predicted_cities', 'predicted_countries'],
        right_on=['alternatenames', 'country'],
        validate='m:1'
    )
    
    df_prediction.rename(columns={'latitude': 'predicted_lat', 'longitude': 'predicted_lon'}, inplace=True)
    
    del df_prediction['alternatenames']
    del df_prediction['country']
    
    df_prediction = pd.merge(
        left=df_prediction,
        right=geonames.loc[:,['alternatenames', 'country', 'latitude', 'longitude']],
        how='left',
        left_on=['real_cities', 'real_countries'],
        right_on=['alternatenames', 'country'],
        validate='m:1'
    )
    
    del df_prediction['alternatenames']
    del df_prediction['country']
    
    df_prediction.rename(columns={'latitude': 'real_lat', 'longitude': 'real_lon'}, inplace=True)
    
    #print(df_prediction.head(5))
    
    print("Total NaN: ", df_prediction.shape[0]-df_prediction.dropna(subset=['real_lat', 'real_lon', 'predicted_lat', 'predicted_lon']).shape[0])

    return df_prediction.apply(determine_distance, axis=1)

def accuracy_161km(real_place, pred_place):
    dif_distance = get_difference_distance(pred_place, real_place)
    
    total_positives = 0
    
    for val in dif_distance:
        if val <= 161:
            total_positives += 1
    
    return total_positives / len(dif_distance)

# %%
users_with_mentions = pd.read_pickle(dosTPath + "users_with_mentions_popular.pkl")
users_with_mentions.head(3)
# Out:
#                    id           place_name place_country   latitude  \
# 0  773970163502870528  guadalajara de buga      colombia   3.900890
# 1            77573705                quito       ecuador  -0.229850
# 2  782687718576840704               tolosa        españa  43.134838
#
#    longitude                                    users_mentioned
# 0 -76.297829                                                NaN
# 1 -78.524948                                        [343818604]
# 2  -2.078010  [17192256, 17192256, 17192256, 17192256, 10048...

# %%
users_with_mentions["unified_place"] = users_with_mentions["place_name"] + ',' + users_with_mentions["place_country"]

# %%
min_determined_place = users_with_mentions.loc[:, ["id", "unified_place"]].groupby("unified_place").\
                        count().reset_index()

min_determined_place = min_determined_place.loc[min_determined_place["id"] >= 1200, :]
min_determined_place.shape
# Out:
# (23, 2)

# %%
users_train = pd.merge(
    left=users_with_mentions,
    right=min_determined_place.loc[:, ['unified_place']],
    how='inner',
    left_on='unified_place',
    right_on='unified_place',
    validate='m:1'
)

users_train.shape
# Out:
# (79642, 7)

# %%
users_train.dropna(subset=["users_mentioned"], inplace=True)
users_train.reset_index(drop=True, inplace=True)
users_train.shape
# Out:
# (51347, 7)

# %% [markdown]
# Armado de matriz de adyascencia

# %%
#users_train["users_mentioned"] = users_train["users_mentioned"].apply(lambda x: list(map(int, x)))

# %%
users_ids = users_train["id"].unique()

set_users = set(users_ids)

for x in users_train["users_mentioned"].values:
    set_users |= set(x)

mentioned_users = list(set_users.difference(set(users_ids)))

total_users = list(users_ids) + mentioned_users
len(total_users)
# Out:
# 576576

# %%
#Verify order

value = True

for i in range(0, len(users_train["id"])):
    if total_users[i] != users_train["id"][i]:
        value = False

print(value)
# Out:
# True

# %%
vectorizer = CountVectorizer(
    strip_accents=None,
    lowercase=False,
    vocabulary=total_users,
    analyzer=lambda x: x
)

vector_of_mentions = vectorizer.fit_transform(users_train["users_mentioned"]).astype(np.uint8)
vector_of_mentions
# Out:
# <59942x606778 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 2279883 stored elements in Compressed Sparse Row format>

# %%
cx = vector_of_mentions.tocoo()
edges = []

for i,j,v in zip(cx.row, cx.col, cx.data):
    if v <= 0:
        continue
        
    #format_str = total_users[i] + " " + total_users[j] + " " + str(v)
    format_str = str(i) + " " + str(j) + " " + str(v)
    edges.append(format_str)

# %%
df = pd.DataFrame({"edges": edges})
df.to_csv("../../results/matrix/mentions/edges_mentions_weighted.csv", header=False, index=False)

# %% [markdown]
# Comentions

# %%
vectorizer = CountVectorizer(
    strip_accents=None,
    lowercase=False,
    vocabulary=total_users_pop,
    analyzer=lambda x: x,
    binary=True
)

vector_of_mentions = vectorizer.fit_transform(users_train_fil_pop["users_mentioned"]).astype(np.uint8)
vector_of_mentions
# Out:
# <51347x583325 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 1007618 stored elements in Compressed Sparse Row format>

# %%
vector_of_co_mentions = vector_of_mentions.dot(vector_of_mentions.T)
vector_of_co_mentions.setdiag(0, k=0)
vector_of_co_mentions
# Out:
# <51347x51347 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 2211299 stored elements in Compressed Sparse Row format>

# %%
cx = vector_of_co_mentions.tocoo()
edges = []
already_passed = {}

for i in range(vector_of_co_mentions.shape[0]):
    already_passed[i] = []

for i,j,v in zip(cx.row, cx.col, cx.data):
    if v <= 0:
        continue
    
    if i in already_passed[j]:
        continue
        
    format_str = str(i) + " " + str(j) + " " + str(v)
    edges.append(format_str)
    
    already_passed[i].append(j)

# %%
len(edges)
# Out:
# 1079976

# %%
df = pd.DataFrame({"edges": edges})
df.to_csv("../../results/matrix/mentions/edges_comentions_weighted.csv", header=False, index=False)

# %% [markdown]
# # Busqueda comunidades oslom

# %%
start = time.time()

# !cd ../../oslom/OSLOM2 && \
./oslom_dir -f ../../results/matrix/mentions/edges_mentions_weighted.csv -w -r 1 -hr 0 -seed 430430 -cp 0.5

end = time.time()
print(end - start)
# Out:
# setting -f
# setting -w
# setting -r
# setting -hr
# setting -seed
# setting -cp
# **************************************
# Threshold:			0.1
# Network file:			../../results/matrix/mentions/edges_mentions_weighted.csv
# Weighted: yes
# First Level Runs:			1
# Higher Level Runs:			0
# -cp:			0.5
# Random number generator seed:			430430
# **************************************
#
# allocating 2279877 factorials...
# done
# mkdir: cannot create directory ‘../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files’: File exists
# output files will be written in directory: ../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files
# network:: 606776 nodes and 2.27988e+06 stubs;	 average degree = 3.75736
# STARTING! HIERARCHICAL LEVEL: 0
# ***************************************************************** RUN: #1
# iteration: 0 number of modules: 45230
# iteration: 20 number of modules: 27370
# collection done
#
#
# checked 0 modules 0 were found significant.  Modules to check: 27973. Percentage nodes done: 0
# checked 100 modules 92 were found significant.  Modules to check: 27873. Percentage nodes done: 0.333359
# checked 200 modules 181 were found significant.  Modules to check: 27773. Percentage nodes done: 0.351734
# checked 300 modules 264 were found significant.  Modules to check: 27673. Percentage nodes done: 0.366137
# checked 400 modules 346 were found significant.  Modules to check: 27573. Percentage nodes done: 0.378115
# checked 500 modules 430 were found significant.  Modules to check: 27473. Percentage nodes done: 0.389137
# checked 600 modules 518 were found significant.  Modules to check: 27373. Percentage nodes done: 0.403371
# checked 700 modules 602 were found significant.  Modules to check: 27273. Percentage nodes done: 0.418313
# checked 800 modules 687 were found significant.  Modules to check: 27173. Percentage nodes done: 0.42147
# checked 900 modules 760 were found significant.  Modules to check: 27073. Percentage nodes done: 0.427706
# checked 1000 modules 840 were found significant.  Modules to check: 26973. Percentage nodes done: 0.436741
# checked 1100 modules 919 were found significant.  Modules to check: 26873. Percentage nodes done: 0.44317
# checked 1200 modules 1005 were found significant.  Modules to check: 26773. Percentage nodes done: 0.449894
# checked 1300 modules 1082 were found significant.  Modules to check: 26673. Percentage nodes done: 0.455109
# checked 1400 modules 1150 were found significant.  Modules to check: 26573. Percentage nodes done: 0.460476
# checked 1500 modules 1233 were found significant.  Modules to check: 26473. Percentage nodes done: 0.465104
# checked 1600 modules 1310 were found significant.  Modules to check: 26373. Percentage nodes done: 0.472632
# checked 1700 modules 1385 were found significant.  Modules to check: 26273. Percentage nodes done: 0.479032
# checked 1800 modules 1474 were found significant.  Modules to check: 26173. Percentage nodes done: 0.485807
# checked 1900 modules 1549 were found significant.  Modules to check: 26073. Percentage nodes done: 0.491064
# checked 2000 modules 1626 were found significant.  Modules to check: 25973. Percentage nodes done: 0.496485
# checked 2100 modules 1690 were found significant.  Modules to check: 25873. Percentage nodes done: 0.499914
# checked 2200 modules 1761 were found significant.  Modules to check: 25773. Percentage nodes done: 0.503716
# checked 2300 modules 1823 were found significant.  Modules to check: 25673. Percentage nodes done: 0.507194
# checked 2400 modules 1894 were found significant.  Modules to check: 25573. Percentage nodes done: 0.512283
# checked 2500 modules 1961 were found significant.  Modules to check: 25473. Percentage nodes done: 0.515548
# checked 2600 modules 2028 were found significant.  Modules to check: 25373. Percentage nodes done: 0.518465
# checked 2700 modules 2104 were found significant.  Modules to check: 25273. Percentage nodes done: 0.52475
# checked 2800 modules 2176 were found significant.  Modules to check: 25173. Percentage nodes done: 0.532551
# checked 2900 modules 2249 were found significant.  Modules to check: 25073. Percentage nodes done: 0.536475
# checked 3000 modules 2326 were found significant.  Modules to check: 24973. Percentage nodes done: 0.541056
# checked 3100 modules 2413 were found significant.  Modules to check: 24873. Percentage nodes done: 0.547599
# checked 3200 modules 2499 were found significant.  Modules to check: 24773. Percentage nodes done: 0.553231
# checked 3300 modules 2587 were found significant.  Modules to check: 24673. Percentage nodes done: 0.558659
# checked 3400 modules 2669 were found significant.  Modules to check: 24573. Percentage nodes done: 0.563333
# checked 3500 modules 2751 were found significant.  Modules to check: 24473. Percentage nodes done: 0.567506
# checked 3600 modules 2829 were found significant.  Modules to check: 24373. Percentage nodes done: 0.571807
# checked 3700 modules 2905 were found significant.  Modules to check: 24273. Percentage nodes done: 0.576298
# checked 3800 modules 2982 were found significant.  Modules to check: 24173. Percentage nodes done: 0.581065
# checked 3900 modules 3075 were found significant.  Modules to check: 24073. Percentage nodes done: 0.587457
# checked 4000 modules 3168 were found significant.  Modules to check: 23973. Percentage nodes done: 0.594081
# checked 4100 modules 3263 were found significant.  Modules to check: 23873. Percentage nodes done: 0.598709
# checked 4200 modules 3351 were found significant.  Modules to check: 23773. Percentage nodes done: 0.602941
# checked 4300 modules 3443 were found significant.  Modules to check: 23673. Percentage nodes done: 0.60791
# checked 4400 modules 3531 were found significant.  Modules to check: 23573. Percentage nodes done: 0.61318
# checked 4500 modules 3616 were found significant.  Modules to check: 23473. Percentage nodes done: 0.615949
# checked 4600 modules 3698 were found significant.  Modules to check: 23373. Percentage nodes done: 0.619322
# checked 4700 modules 3766 were found significant.  Modules to check: 23273. Percentage nodes done: 0.622605
# checked 4800 modules 3857 were found significant.  Modules to check: 23173. Percentage nodes done: 0.6269
# checked 4900 modules 3941 were found significant.  Modules to check: 23073. Percentage nodes done: 0.630493
# checked 5000 modules 4014 were found significant.  Modules to check: 22973. Percentage nodes done: 0.634513
# checked 5100 modules 4084 were found significant.  Modules to check: 22873. Percentage nodes done: 0.637354
# checked 5200 modules 4158 were found significant.  Modules to check: 22773. Percentage nodes done: 0.640924
# checked 5300 modules 4248 were found significant.  Modules to check: 22673. Percentage nodes done: 0.645126
# checked 5400 modules 4331 were found significant.  Modules to check: 22573. Percentage nodes done: 0.648734
# checked 5500 modules 4419 were found significant.  Modules to check: 22473. Percentage nodes done: 0.652396
# checked 5600 modules 4497 were found significant.  Modules to check: 22373. Percentage nodes done: 0.655471
# checked 5700 modules 4579 were found significant.  Modules to check: 22273. Percentage nodes done: 0.658424
# checked 5800 modules 4650 were found significant.  Modules to check: 22173. Percentage nodes done: 0.661
# checked 5900 modules 4736 were found significant.  Modules to check: 22073. Percentage nodes done: 0.663311
# checked 6000 modules 4816 were found significant.  Modules to check: 21973. Percentage nodes done: 0.666084
# checked 6100 modules 4892 were found significant.  Modules to check: 21873. Percentage nodes done: 0.668617
# checked 6200 modules 4976 were found significant.  Modules to check: 21773. Percentage nodes done: 0.671487
# checked 6300 modules 5049 were found significant.  Modules to check: 21673. Percentage nodes done: 0.673563
# checked 6400 modules 5122 were found significant.  Modules to check: 21573. Percentage nodes done: 0.675541
# checked 6500 modules 5197 were found significant.  Modules to check: 21473. Percentage nodes done: 0.678316
# checked 6600 modules 5273 were found significant.  Modules to check: 21373. Percentage nodes done: 0.681302
# checked 6700 modules 5338 were found significant.  Modules to check: 21273. Percentage nodes done: 0.684435
# checked 6800 modules 5408 were found significant.  Modules to check: 21173. Percentage nodes done: 0.687362
# checked 6900 modules 5483 were found significant.  Modules to check: 21073. Percentage nodes done: 0.690075
# checked 7000 modules 5557 were found significant.  Modules to check: 20973. Percentage nodes done: 0.693131
# checked 7100 modules 5633 were found significant.  Modules to check: 20873. Percentage nodes done: 0.695787
# checked 7200 modules 5711 were found significant.  Modules to check: 20773. Percentage nodes done: 0.697824
# checked 7300 modules 5786 were found significant.  Modules to check: 20673. Percentage nodes done: 0.700768
# checked 7400 modules 5851 were found significant.  Modules to check: 20573. Percentage nodes done: 0.706948
# checked 7500 modules 5925 were found significant.  Modules to check: 20473. Percentage nodes done: 0.710875
# checked 7600 modules 6002 were found significant.  Modules to check: 20373. Percentage nodes done: 0.714742
# checked 7700 modules 6065 were found significant.  Modules to check: 20273. Percentage nodes done: 0.717444
# checked 7800 modules 6129 were found significant.  Modules to check: 20173. Percentage nodes done: 0.720612
# checked 7900 modules 6194 were found significant.  Modules to check: 20073. Percentage nodes done: 0.722804
# checked 8000 modules 6260 were found significant.  Modules to check: 19973. Percentage nodes done: 0.724406
# checked 8100 modules 6319 were found significant.  Modules to check: 19873. Percentage nodes done: 0.726243
# checked 8200 modules 6378 were found significant.  Modules to check: 19773. Percentage nodes done: 0.728913
# checked 8300 modules 6445 were found significant.  Modules to check: 19673. Percentage nodes done: 0.732081
# checked 8400 modules 6515 were found significant.  Modules to check: 19573. Percentage nodes done: 0.734324
# checked 8500 modules 6569 were found significant.  Modules to check: 19473. Percentage nodes done: 0.736081
# checked 8600 modules 6621 were found significant.  Modules to check: 19373. Percentage nodes done: 0.737763
# checked 8700 modules 6663 were found significant.  Modules to check: 19273. Percentage nodes done: 0.739096
# checked 8800 modules 6705 were found significant.  Modules to check: 19173. Percentage nodes done: 0.740596
# checked 8900 modules 6739 were found significant.  Modules to check: 19073. Percentage nodes done: 0.741901
# checked 9000 modules 6808 were found significant.  Modules to check: 18973. Percentage nodes done: 0.743531
# checked 9100 modules 6864 were found significant.  Modules to check: 18873. Percentage nodes done: 0.745786
# checked 9200 modules 6948 were found significant.  Modules to check: 18773. Percentage nodes done: 0.748298
# checked 9300 modules 7001 were found significant.  Modules to check: 18673. Percentage nodes done: 0.750048
# checked 9400 modules 7057 were found significant.  Modules to check: 18573. Percentage nodes done: 0.751584
# checked 9500 modules 7105 were found significant.  Modules to check: 18473. Percentage nodes done: 0.753337
# checked 9600 modules 7151 were found significant.  Modules to check: 18373. Percentage nodes done: 0.754901
# checked 9700 modules 7211 were found significant.  Modules to check: 18273. Percentage nodes done: 0.756699
# checked 9800 modules 7269 were found significant.  Modules to check: 18173. Percentage nodes done: 0.757945
# checked 9900 modules 7336 were found significant.  Modules to check: 18073. Percentage nodes done: 0.760434
# checked 10000 modules 7406 were found significant.  Modules to check: 17973. Percentage nodes done: 0.762843
# checked 10100 modules 7467 were found significant.  Modules to check: 17873. Percentage nodes done: 0.764986
# checked 10200 modules 7543 were found significant.  Modules to check: 17773. Percentage nodes done: 0.767478
# checked 10300 modules 7604 were found significant.  Modules to check: 17673. Percentage nodes done: 0.769515
# checked 10400 modules 7690 were found significant.  Modules to check: 17573. Percentage nodes done: 0.772107
# checked 10500 modules 7755 were found significant.  Modules to check: 17473. Percentage nodes done: 0.774464
# checked 10600 modules 7819 were found significant.  Modules to check: 17373. Percentage nodes done: 0.776229
# checked 10700 modules 7897 were found significant.  Modules to check: 17273. Percentage nodes done: 0.778462
# checked 10800 modules 7968 were found significant.  Modules to check: 17173. Percentage nodes done: 0.780323
# checked 10900 modules 8040 were found significant.  Modules to check: 17073. Percentage nodes done: 0.782277
# checked 11000 modules 8114 were found significant.  Modules to check: 16973. Percentage nodes done: 0.784087
# checked 11100 modules 8197 were found significant.  Modules to check: 16873. Percentage nodes done: 0.786277
# checked 11200 modules 8278 were found significant.  Modules to check: 16773. Percentage nodes done: 0.788499
# checked 11300 modules 8351 were found significant.  Modules to check: 16673. Percentage nodes done: 0.79018
# checked 11400 modules 8420 were found significant.  Modules to check: 16573. Percentage nodes done: 0.7922
# checked 11500 modules 8476 were found significant.  Modules to check: 16473. Percentage nodes done: 0.793851
# checked 11600 modules 8542 were found significant.  Modules to check: 16373. Percentage nodes done: 0.795719
# checked 11700 modules 8614 were found significant.  Modules to check: 16273. Percentage nodes done: 0.797424
# checked 11800 modules 8682 were found significant.  Modules to check: 16173. Percentage nodes done: 0.799483
# checked 11900 modules 8753 were found significant.  Modules to check: 16073. Percentage nodes done: 0.801507
# checked 12000 modules 8802 were found significant.  Modules to check: 15973. Percentage nodes done: 0.802875
# checked 12100 modules 8877 were found significant.  Modules to check: 15873. Percentage nodes done: 0.80471
# checked 12200 modules 8933 were found significant.  Modules to check: 15773. Percentage nodes done: 0.806817
# checked 12300 modules 9000 were found significant.  Modules to check: 15673. Percentage nodes done: 0.808855
# checked 12400 modules 9083 were found significant.  Modules to check: 15573. Percentage nodes done: 0.811064
# checked 12500 modules 9154 were found significant.  Modules to check: 15473. Percentage nodes done: 0.813396
# checked 12600 modules 9237 were found significant.  Modules to check: 15373. Percentage nodes done: 0.815396
# checked 12700 modules 9319 were found significant.  Modules to check: 15273. Percentage nodes done: 0.817656
# checked 12800 modules 9398 were found significant.  Modules to check: 15173. Percentage nodes done: 0.819719
# checked 12900 modules 9473 were found significant.  Modules to check: 15073. Percentage nodes done: 0.82161
# checked 13000 modules 9560 were found significant.  Modules to check: 14973. Percentage nodes done: 0.823589
# checked 13100 modules 9632 were found significant.  Modules to check: 14873. Percentage nodes done: 0.825455
# checked 13200 modules 9711 were found significant.  Modules to check: 14773. Percentage nodes done: 0.827195
# checked 13300 modules 9787 were found significant.  Modules to check: 14673. Percentage nodes done: 0.829092
# checked 13400 modules 9860 were found significant.  Modules to check: 14573. Percentage nodes done: 0.830964
# checked 13500 modules 9934 were found significant.  Modules to check: 14473. Percentage nodes done: 0.8329
# checked 13600 modules 10004 were found significant.  Modules to check: 14373. Percentage nodes done: 0.834814
# checked 13700 modules 10075 were found significant.  Modules to check: 14273. Percentage nodes done: 0.836347
# checked 13800 modules 10139 were found significant.  Modules to check: 14173. Percentage nodes done: 0.837906
# checked 13900 modules 10207 were found significant.  Modules to check: 14073. Percentage nodes done: 0.839554
# checked 14000 modules 10286 were found significant.  Modules to check: 13973. Percentage nodes done: 0.84094
# checked 14100 modules 10342 were found significant.  Modules to check: 13873. Percentage nodes done: 0.842578
# checked 14200 modules 10416 were found significant.  Modules to check: 13773. Percentage nodes done: 0.844173
# checked 14300 modules 10478 were found significant.  Modules to check: 13673. Percentage nodes done: 0.84562
# checked 14400 modules 10538 were found significant.  Modules to check: 13573. Percentage nodes done: 0.847082
# checked 14500 modules 10592 were found significant.  Modules to check: 13473. Percentage nodes done: 0.848461
# checked 14600 modules 10645 were found significant.  Modules to check: 13373. Percentage nodes done: 0.84966
# checked 14700 modules 10702 were found significant.  Modules to check: 13273. Percentage nodes done: 0.850897
# checked 14800 modules 10756 were found significant.  Modules to check: 13173. Percentage nodes done: 0.852186
# checked 14900 modules 10813 were found significant.  Modules to check: 13073. Percentage nodes done: 0.853658
# checked 15000 modules 10874 were found significant.  Modules to check: 12973. Percentage nodes done: 0.854968
# checked 15100 modules 10931 were found significant.  Modules to check: 12873. Percentage nodes done: 0.856239
# checked 15200 modules 10983 were found significant.  Modules to check: 12773. Percentage nodes done: 0.857341
# checked 15300 modules 11018 were found significant.  Modules to check: 12673. Percentage nodes done: 0.858439
# checked 15400 modules 11062 were found significant.  Modules to check: 12573. Percentage nodes done: 0.859426
# checked 15500 modules 11128 were found significant.  Modules to check: 12473. Percentage nodes done: 0.861015
# checked 15600 modules 11219 were found significant.  Modules to check: 12373. Percentage nodes done: 0.862681
# checked 15700 modules 11305 were found significant.  Modules to check: 12273. Percentage nodes done: 0.864449
# checked 15800 modules 11377 were found significant.  Modules to check: 12173. Percentage nodes done: 0.866087
# checked 15900 modules 11460 were found significant.  Modules to check: 12073. Percentage nodes done: 0.867696
# checked 16000 modules 11534 were found significant.  Modules to check: 11973. Percentage nodes done: 0.869289
# checked 16100 modules 11605 were found significant.  Modules to check: 11873. Percentage nodes done: 0.870628
# checked 16200 modules 11656 were found significant.  Modules to check: 11773. Percentage nodes done: 0.871806
# checked 16300 modules 11719 were found significant.  Modules to check: 11673. Percentage nodes done: 0.873164
# checked 16400 modules 11775 were found significant.  Modules to check: 11573. Percentage nodes done: 0.874336
# checked 16500 modules 11840 were found significant.  Modules to check: 11473. Percentage nodes done: 0.875409
# checked 16600 modules 11904 were found significant.  Modules to check: 11373. Percentage nodes done: 0.876742
# checked 16700 modules 11958 were found significant.  Modules to check: 11273. Percentage nodes done: 0.877805
# checked 16800 modules 12009 were found significant.  Modules to check: 11173. Percentage nodes done: 0.879145
# checked 16900 modules 12063 were found significant.  Modules to check: 11073. Percentage nodes done: 0.880125
# checked 17000 modules 12110 were found significant.  Modules to check: 10973. Percentage nodes done: 0.881187
# checked 17100 modules 12167 were found significant.  Modules to check: 10873. Percentage nodes done: 0.882299
# checked 17200 modules 12219 were found significant.  Modules to check: 10773. Percentage nodes done: 0.883603
# checked 17300 modules 12279 were found significant.  Modules to check: 10673. Percentage nodes done: 0.884873
# checked 17400 modules 12321 were found significant.  Modules to check: 10573. Percentage nodes done: 0.885973
# checked 17500 modules 12374 were found significant.  Modules to check: 10473. Percentage nodes done: 0.887049
# checked 17600 modules 12419 were found significant.  Modules to check: 10373. Percentage nodes done: 0.888465
# checked 17700 modules 12472 were found significant.  Modules to check: 10273. Percentage nodes done: 0.889683
# checked 17800 modules 12530 were found significant.  Modules to check: 10173. Percentage nodes done: 0.891113
# checked 17900 modules 12573 were found significant.  Modules to check: 10073. Percentage nodes done: 0.892006
# checked 18000 modules 12625 were found significant.  Modules to check: 9973. Percentage nodes done: 0.893226
# checked 18100 modules 12673 were found significant.  Modules to check: 9873. Percentage nodes done: 0.894447
# checked 18200 modules 12726 were found significant.  Modules to check: 9773. Percentage nodes done: 0.895695
# checked 18300 modules 12774 were found significant.  Modules to check: 9673. Percentage nodes done: 0.896848
# checked 18400 modules 12826 were found significant.  Modules to check: 9573. Percentage nodes done: 0.898073
# checked 18500 modules 12882 were found significant.  Modules to check: 9473. Percentage nodes done: 0.899055
# checked 18600 modules 12926 were found significant.  Modules to check: 9373. Percentage nodes done: 0.900397
# checked 18700 modules 12966 were found significant.  Modules to check: 9273. Percentage nodes done: 0.901413
# checked 18800 modules 13021 were found significant.  Modules to check: 9173. Percentage nodes done: 0.902724
# checked 18900 modules 13079 were found significant.  Modules to check: 9073. Percentage nodes done: 0.903767
# checked 19000 modules 13127 were found significant.  Modules to check: 8973. Percentage nodes done: 0.904784
# checked 19100 modules 13175 were found significant.  Modules to check: 8873. Percentage nodes done: 0.905965
# checked 19200 modules 13221 were found significant.  Modules to check: 8773. Percentage nodes done: 0.907173
# checked 19300 modules 13265 were found significant.  Modules to check: 8673. Percentage nodes done: 0.908075
# checked 19400 modules 13309 were found significant.  Modules to check: 8573. Percentage nodes done: 0.909016
# checked 19500 modules 13346 were found significant.  Modules to check: 8473. Percentage nodes done: 0.909878
# checked 19600 modules 13391 were found significant.  Modules to check: 8373. Percentage nodes done: 0.911022
# checked 19700 modules 13417 were found significant.  Modules to check: 8273. Percentage nodes done: 0.912088
# checked 19800 modules 13475 were found significant.  Modules to check: 8173. Percentage nodes done: 0.913479
# checked 19900 modules 13516 were found significant.  Modules to check: 8073. Percentage nodes done: 0.914293
# checked 20000 modules 13566 were found significant.  Modules to check: 7973. Percentage nodes done: 0.915427
# checked 20100 modules 13620 were found significant.  Modules to check: 7873. Percentage nodes done: 0.916294
# checked 20200 modules 13663 were found significant.  Modules to check: 7773. Percentage nodes done: 0.917103
# checked 20300 modules 13717 were found significant.  Modules to check: 7673. Percentage nodes done: 0.918568
# checked 20400 modules 13760 were found significant.  Modules to check: 7573. Percentage nodes done: 0.920285
# checked 20500 modules 13802 were found significant.  Modules to check: 7473. Percentage nodes done: 0.921841
# checked 20600 modules 13844 were found significant.  Modules to check: 7373. Percentage nodes done: 0.923062
# checked 20700 modules 13873 were found significant.  Modules to check: 7273. Percentage nodes done: 0.924201
# checked 20800 modules 13911 were found significant.  Modules to check: 7173. Percentage nodes done: 0.925559
# checked 20900 modules 13954 were found significant.  Modules to check: 7073. Percentage nodes done: 0.926353
# checked 21000 modules 13992 were found significant.  Modules to check: 6973. Percentage nodes done: 0.927192
# checked 21100 modules 14048 were found significant.  Modules to check: 6873. Percentage nodes done: 0.929144
# checked 21200 modules 14106 were found significant.  Modules to check: 6773. Percentage nodes done: 0.931143
# checked 21300 modules 14165 were found significant.  Modules to check: 6673. Percentage nodes done: 0.932997
# checked 21400 modules 14213 were found significant.  Modules to check: 6573. Percentage nodes done: 0.934439
# checked 21500 modules 14253 were found significant.  Modules to check: 6473. Percentage nodes done: 0.935795
# checked 21600 modules 14301 were found significant.  Modules to check: 6373. Percentage nodes done: 0.937125
# checked 21700 modules 14360 were found significant.  Modules to check: 6273. Percentage nodes done: 0.939032
# checked 21800 modules 14419 were found significant.  Modules to check: 6173. Percentage nodes done: 0.940513
# checked 21900 modules 14466 were found significant.  Modules to check: 6073. Percentage nodes done: 0.941896
# checked 22000 modules 14503 were found significant.  Modules to check: 5973. Percentage nodes done: 0.943223
# checked 22100 modules 14538 were found significant.  Modules to check: 5873. Percentage nodes done: 0.94436
# checked 22200 modules 14570 were found significant.  Modules to check: 5773. Percentage nodes done: 0.945243
# checked 22300 modules 14615 were found significant.  Modules to check: 5673. Percentage nodes done: 0.946532
# checked 22400 modules 14649 were found significant.  Modules to check: 5573. Percentage nodes done: 0.947491
# checked 22500 modules 14692 were found significant.  Modules to check: 5473. Percentage nodes done: 0.94849
# checked 22600 modules 14748 were found significant.  Modules to check: 5373. Percentage nodes done: 0.949736
# checked 22700 modules 14785 were found significant.  Modules to check: 5273. Percentage nodes done: 0.95071
# checked 22800 modules 14825 were found significant.  Modules to check: 5173. Percentage nodes done: 0.951658
# checked 22900 modules 14854 were found significant.  Modules to check: 5073. Percentage nodes done: 0.952482
# checked 23000 modules 14884 were found significant.  Modules to check: 4973. Percentage nodes done: 0.953421
# checked 23100 modules 14908 were found significant.  Modules to check: 4873. Percentage nodes done: 0.954444
# checked 23200 modules 14951 were found significant.  Modules to check: 4773. Percentage nodes done: 0.95559
# checked 23300 modules 14990 were found significant.  Modules to check: 4673. Percentage nodes done: 0.956684
# checked 23400 modules 15030 were found significant.  Modules to check: 4573. Percentage nodes done: 0.957439
# checked 23500 modules 15070 were found significant.  Modules to check: 4473. Percentage nodes done: 0.958512
# checked 23600 modules 15117 were found significant.  Modules to check: 4373. Percentage nodes done: 0.959718
# checked 23700 modules 15172 were found significant.  Modules to check: 4273. Percentage nodes done: 0.961363
# checked 23800 modules 15209 were found significant.  Modules to check: 4173. Percentage nodes done: 0.962373
# checked 23900 modules 15246 were found significant.  Modules to check: 4073. Percentage nodes done: 0.963319
# checked 24000 modules 15286 were found significant.  Modules to check: 3973. Percentage nodes done: 0.964209
# checked 24100 modules 15321 were found significant.  Modules to check: 3873. Percentage nodes done: 0.965191
# checked 24200 modules 15349 were found significant.  Modules to check: 3773. Percentage nodes done: 0.96622
# checked 24300 modules 15392 were found significant.  Modules to check: 3673. Percentage nodes done: 0.96721
# checked 24400 modules 15439 were found significant.  Modules to check: 3573. Percentage nodes done: 0.968537
# checked 24500 modules 15478 were found significant.  Modules to check: 3473. Percentage nodes done: 0.969804
# checked 24600 modules 15531 were found significant.  Modules to check: 3373. Percentage nodes done: 0.971029
# checked 24700 modules 15574 were found significant.  Modules to check: 3273. Percentage nodes done: 0.972122
# checked 24800 modules 15609 were found significant.  Modules to check: 3173. Percentage nodes done: 0.972964
# checked 24900 modules 15644 were found significant.  Modules to check: 3073. Percentage nodes done: 0.973885
# checked 25000 modules 15684 were found significant.  Modules to check: 2973. Percentage nodes done: 0.974722
# checked 25100 modules 15719 were found significant.  Modules to check: 2873. Percentage nodes done: 0.975589
# checked 25200 modules 15748 were found significant.  Modules to check: 2773. Percentage nodes done: 0.976413
# checked 25300 modules 15775 were found significant.  Modules to check: 2673. Percentage nodes done: 0.977257
# checked 25400 modules 15813 were found significant.  Modules to check: 2573. Percentage nodes done: 0.978124
# checked 25500 modules 15851 were found significant.  Modules to check: 2473. Percentage nodes done: 0.979302
# checked 25600 modules 15877 were found significant.  Modules to check: 2373. Percentage nodes done: 0.980164
# checked 25700 modules 15902 were found significant.  Modules to check: 2273. Percentage nodes done: 0.981019
# checked 25800 modules 15936 were found significant.  Modules to check: 2173. Percentage nodes done: 0.981733
# checked 25900 modules 15967 were found significant.  Modules to check: 2073. Percentage nodes done: 0.982522
# checked 26000 modules 16006 were found significant.  Modules to check: 1973. Percentage nodes done: 0.983538
# checked 26100 modules 16047 were found significant.  Modules to check: 1873. Percentage nodes done: 0.984352
# checked 26200 modules 16075 were found significant.  Modules to check: 1773. Percentage nodes done: 0.985087
# checked 26300 modules 16112 were found significant.  Modules to check: 1673. Percentage nodes done: 0.986021
# checked 26400 modules 16135 were found significant.  Modules to check: 1573. Percentage nodes done: 0.986825
# checked 26500 modules 16171 were found significant.  Modules to check: 1473. Percentage nodes done: 0.987584
# checked 26600 modules 16200 were found significant.  Modules to check: 1373. Percentage nodes done: 0.988264
# checked 26700 modules 16237 were found significant.  Modules to check: 1273. Percentage nodes done: 0.989146
# checked 26800 modules 16271 were found significant.  Modules to check: 1173. Percentage nodes done: 0.9898
# checked 26900 modules 16304 were found significant.  Modules to check: 1073. Percentage nodes done: 0.990422
# checked 27000 modules 16337 were found significant.  Modules to check: 973. Percentage nodes done: 0.991305
# checked 27100 modules 16358 were found significant.  Modules to check: 873. Percentage nodes done: 0.991959
# checked 27200 modules 16391 were found significant.  Modules to check: 773. Percentage nodes done: 0.992973
# checked 27300 modules 16432 were found significant.  Modules to check: 673. Percentage nodes done: 0.993742
# checked 27400 modules 16463 were found significant.  Modules to check: 573. Percentage nodes done: 0.994392
# checked 27500 modules 16502 were found significant.  Modules to check: 473. Percentage nodes done: 0.995649
# checked 27600 modules 16537 were found significant.  Modules to check: 373. Percentage nodes done: 0.996791
# checked 27700 modules 16568 were found significant.  Modules to check: 273. Percentage nodes done: 0.997755
# checked 27800 modules 16611 were found significant.  Modules to check: 173. Percentage nodes done: 0.998794
# checked 27900 modules 16640 were found significant.  Modules to check: 73. Percentage nodes done: 0.999552
# significance check done
#
#
# checking unions of not significant modules, modules to check: 11323
# iteration: 0 number of modules: 9137
# collection done
#
#
# checking unions of not significant modules, modules to check: 963
# iteration: 0 number of modules: 595
# collection done
#
#
# checking unions of not significant modules done
#
#
# ***************************************************************************
# COLLECTING SIGNIFICANT MODULES DONE
#
# minimality check: 2641 modules to check, run: 0
# minimality check: 24 modules to check, run: 1
# ***************************************************************************
# MINIMALITY CHECK DONE
# checking similar modules
#
# check unions of modules using community network
#
# iteration: 0 number of modules: 65764
# collection done
#
#
# possible fusions to check: 57117
# checked 0 unions. Fused: 0
# checked 100 unions. Fused: 0
# checked 200 unions. Fused: 0
# checked 300 unions. Fused: 0
# checked 400 unions. Fused: 0
# checked 500 unions. Fused: 0
# checked 600 unions. Fused: 0
# checked 700 unions. Fused: 0
# checked 800 unions. Fused: 0
# checked 900 unions. Fused: 0
# checked 1000 unions. Fused: 0
# checked 1100 unions. Fused: 0
# checked 1200 unions. Fused: 0
# checked 1300 unions. Fused: 0
# checked 1400 unions. Fused: 0
# checked 1500 unions. Fused: 0
# checked 1600 unions. Fused: 0
# checked 1700 unions. Fused: 0
# checked 1800 unions. Fused: 0
# checked 1900 unions. Fused: 0
# checked 2000 unions. Fused: 0
# checked 2100 unions. Fused: 0
# checked 2200 unions. Fused: 0
# checked 2300 unions. Fused: 0
# checked 2400 unions. Fused: 0
# checked 2600 unions. Fused: 0
# checked 2700 unions. Fused: 0
# checked 2800 unions. Fused: 0
# checked 2900 unions. Fused: 0
# checked 3700 unions. Fused: 0
# checked 3800 unions. Fused: 0
# checked 3900 unions. Fused: 0
# checked 4000 unions. Fused: 0
# checked 4100 unions. Fused: 0
# checked 4200 unions. Fused: 0
# checked 4300 unions. Fused: 0
# checked 4400 unions. Fused: 0
# checked 4500 unions. Fused: 0
# checked 4600 unions. Fused: 0
# checked 4700 unions. Fused: 0
# checked 4800 unions. Fused: 0
# checked 4900 unions. Fused: 0
# checked 5000 unions. Fused: 0
# checked 5400 unions. Fused: 0
# checked 5500 unions. Fused: 0
# checked 5700 unions. Fused: 0
# checked 5800 unions. Fused: 0
# checked 5900 unions. Fused: 0
# checked 6000 unions. Fused: 0
# checked 6400 unions. Fused: 0
# checked 6500 unions. Fused: 0
# checked 6600 unions. Fused: 0
# checked 6700 unions. Fused: 0
# checked 6900 unions. Fused: 0
# checked 7000 unions. Fused: 0
# checked 7900 unions. Fused: 0
# checked 8000 unions. Fused: 0
# checked 8200 unions. Fused: 0
# checked 8300 unions. Fused: 0
# checked 8400 unions. Fused: 0
# checked 8600 unions. Fused: 0
# checked 8700 unions. Fused: 0
# checked 8800 unions. Fused: 0
# checked 8900 unions. Fused: 0
# checked 9200 unions. Fused: 0
# checked 9300 unions. Fused: 0
# checked 9500 unions. Fused: 0
# checked 9900 unions. Fused: 0
# checked 10000 unions. Fused: 0
# checked 10100 unions. Fused: 0
# checked 10400 unions. Fused: 0
# checked 10600 unions. Fused: 0
# checked 10800 unions. Fused: 0
# checked 11000 unions. Fused: 0
# checked 11300 unions. Fused: 0
# checked 11500 unions. Fused: 0
# checked 11600 unions. Fused: 0
# checked 11700 unions. Fused: 0
# checked 11800 unions. Fused: 0
# checked 12500 unions. Fused: 0
# checked 12600 unions. Fused: 0
# checked 12900 unions. Fused: 0
# checked 13200 unions. Fused: 0
# checked 13300 unions. Fused: 0
# checked 13500 unions. Fused: 0
# checked 13600 unions. Fused: 0
# checked 13700 unions. Fused: 0
# checked 13800 unions. Fused: 0
# checked 13900 unions. Fused: 0
# checked 14100 unions. Fused: 0
# checked 14300 unions. Fused: 0
# checked 14400 unions. Fused: 0
# checked 14500 unions. Fused: 0
# checked 14600 unions. Fused: 0
# checked 14700 unions. Fused: 0
# checked 14800 unions. Fused: 0
# checked 15300 unions. Fused: 0
# checked 15400 unions. Fused: 0
# checked 15500 unions. Fused: 0
# checked 15700 unions. Fused: 0
# checked 16000 unions. Fused: 0
# checked 16500 unions. Fused: 0
# checked 17100 unions. Fused: 0
# checked 17200 unions. Fused: 0
# checked 17300 unions. Fused: 0
# checked 17400 unions. Fused: 0
# checked 17500 unions. Fused: 0
# checked 17800 unions. Fused: 0
# checked 17900 unions. Fused: 0
# checked 18000 unions. Fused: 0
# checked 18500 unions. Fused: 0
# checked 18600 unions. Fused: 0
# checked 18700 unions. Fused: 0
# checked 18800 unions. Fused: 0
# checked 19000 unions. Fused: 0
# checked 19100 unions. Fused: 0
# checked 19200 unions. Fused: 0
# checked 19400 unions. Fused: 0
# checked 19500 unions. Fused: 0
# checked 19600 unions. Fused: 0
# checked 19700 unions. Fused: 0
# checked 19800 unions. Fused: 0
# checked 19900 unions. Fused: 0
# checked 20000 unions. Fused: 0
# checked 20100 unions. Fused: 0
# checked 20400 unions. Fused: 0
# checked 20500 unions. Fused: 0
# checked 21900 unions. Fused: 0
# checked 22900 unions. Fused: 0
# checked 24400 unions. Fused: 0
# checked 24700 unions. Fused: 0
# checked 25100 unions. Fused: 0
# checked 25200 unions. Fused: 0
# checked 25400 unions. Fused: 0
# checked 26000 unions. Fused: 0
# checked 26200 unions. Fused: 0
# checked 26400 unions. Fused: 0
# checked 26700 unions. Fused: 0
# checked 26800 unions. Fused: 0
# checked 26900 unions. Fused: 0
# checked 27500 unions. Fused: 0
# checked 27600 unions. Fused: 0
# checked 27900 unions. Fused: 0
# checked 28100 unions. Fused: 0
# checked 28400 unions. Fused: 0
# checked 28700 unions. Fused: 0
# checked 28800 unions. Fused: 0
# checked 29000 unions. Fused: 0
# checked 29400 unions. Fused: 0
# checked 29500 unions. Fused: 0
# checked 29700 unions. Fused: 0
# checked 30900 unions. Fused: 0
# checked 31200 unions. Fused: 0
# checked 31300 unions. Fused: 0
# checked 31400 unions. Fused: 0
# checked 31800 unions. Fused: 0
# checked 31900 unions. Fused: 0
# checked 32000 unions. Fused: 0
# checked 32100 unions. Fused: 0
# checked 32600 unions. Fused: 0
# checked 32700 unions. Fused: 0
# checked 33000 unions. Fused: 0
# checked 33200 unions. Fused: 0
# checked 33300 unions. Fused: 0
# checked 33900 unions. Fused: 0
# checked 34100 unions. Fused: 0
# checked 34200 unions. Fused: 0
# checked 34300 unions. Fused: 0
# checked 34600 unions. Fused: 0
# checked 34900 unions. Fused: 0
# checked 35000 unions. Fused: 0
# checked 35100 unions. Fused: 0
# checked 35400 unions. Fused: 0
# checked 35600 unions. Fused: 0
# checked 36400 unions. Fused: 0
# checked 37000 unions. Fused: 0
# checked 37100 unions. Fused: 0
# checked 37200 unions. Fused: 0
# checked 37300 unions. Fused: 0
# checked 37400 unions. Fused: 0
# checked 37700 unions. Fused: 0
# checked 37900 unions. Fused: 0
# checked 38300 unions. Fused: 0
# checked 38700 unions. Fused: 0
# checked 39000 unions. Fused: 0
# checked 39200 unions. Fused: 0
# checked 39500 unions. Fused: 0
# checked 40100 unions. Fused: 0
# checked 40200 unions. Fused: 0
# checked 40300 unions. Fused: 0
# checked 40500 unions. Fused: 0
# checked 41100 unions. Fused: 0
# checked 42100 unions. Fused: 0
# checked 43200 unions. Fused: 0
# checked 43400 unions. Fused: 0
# checked 44400 unions. Fused: 0
# checked 44600 unions. Fused: 0
# checked 44700 unions. Fused: 0
# checked 44900 unions. Fused: 0
# checked 45000 unions. Fused: 0
# checked 45200 unions. Fused: 0
# checked 45300 unions. Fused: 0
# checked 45400 unions. Fused: 0
# checked 45800 unions. Fused: 0
# checked 45900 unions. Fused: 0
# checked 46000 unions. Fused: 0
# checked 46400 unions. Fused: 0
# checked 46700 unions. Fused: 0
# checked 46800 unions. Fused: 0
# checked 47300 unions. Fused: 0
# checked 47400 unions. Fused: 0
# checked 47500 unions. Fused: 0
# checked 48400 unions. Fused: 0
# checked 48600 unions. Fused: 0
# checked 48700 unions. Fused: 0
# checked 49000 unions. Fused: 0
# checked 49600 unions. Fused: 0
# checked 50000 unions. Fused: 0
# checked 50300 unions. Fused: 0
# checked 50800 unions. Fused: 0
# checked 50900 unions. Fused: 0
# checked 51500 unions. Fused: 0
# checked 52500 unions. Fused: 0
# checked 52600 unions. Fused: 0
# checked 53100 unions. Fused: 0
# checked 53500 unions. Fused: 0
# checked 53700 unions. Fused: 0
# checked 54100 unions. Fused: 0
# checked 54600 unions. Fused: 0
# checked 54900 unions. Fused: 0
# checked 55700 unions. Fused: 0
# checked 56000 unions. Fused: 0
# checked 56200 unions. Fused: 0
# checked 56300 unions. Fused: 0
# checked 56600 unions. Fused: 0
# checked 56700 unions. Fused: 0
# checked 57100 unions. Fused: 0
# checking highly intersecting modules
#
# pairs to check: 3597
# pairs to check: 191
# pairs to check: 33
# pairs to check: 21
# ***************************************************************************
# CHECK UNIONS AND SIMILAR MODULES DONE
# ******** module_collection ******** 2001 modules. writing...
# DONE   ****************************
# pruning all the modules collected. Partitions found: 1
# getting partition from tp-file: ../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files/partitions_level_0
# 2001 groups found
# 2001 bss found
# checking homeless nodes
# assigning homeless nodes. Homeless at this point: 554586
# assigning homeless nodes. Homeless at this point: 165148
# assigning homeless nodes. Homeless at this point: 26619
# assigning homeless nodes. Homeless at this point: 11793
# assigning homeless nodes. Homeless at this point: 10533
# assigning homeless nodes. Homeless at this point: 10317
# assigning homeless nodes. Homeless at this point: 10300
# assigning homeless nodes. Homeless at this point: 10298
# writing final solution in file ../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files/tp
# ******** module_collection ******** 2001 modules. writing...
# DONE   ****************************
# network:: 12299 nodes and 1.05057e+06 stubs;	 average degree = 85.4193
# STARTING! HIERARCHICAL LEVEL: 1
# pruning all the modules collected. Partitions found: 0
# getting partition from tp-file: ../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files/partitions_level_1
# 0 groups found
# 0 bss found
# checking homeless nodes
# writing final solution in file ../../results/matrix/mentions/edges_mentions_weighted.csv_oslo_files/short_tp1
# ******** module_collection ******** 0 modules. writing...
# DONE   ****************************
# hierarchies done *********
# 2436.588244199753

# %%
start = time.time()

# !cd ../../oslom/OSLOM2 && \
./oslom_undir -f ../../results/matrix/mentions/edges_comentions_weighted.csv -w -r 1 -hr 0 -seed 430430 -cp 0.5

end = time.time()
print(end - start)
# Out:
# setting -f
# setting -w
# setting -r
# setting -hr
# setting -seed
# setting -cp
# **************************************
# Threshold:			0.1
# Network file:			../../results/matrix/mentions/edges_comentions_weighted.csv
# Weighted: yes
# First Level Runs:			1
# Higher Level Runs:			0
# -cp:			0.5
# Random number generator seed:			430430
# **************************************
#
# allocating 2159952 factorials...
# done
# mkdir: cannot create directory ‘../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files’: File exists
# output files will be written in directory: ../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files
# network:: 43193 nodes and 2.15995e+06 stubs;	 average degree = 50.007
# STARTING! HIERARCHICAL LEVEL: 0
# ***************************************************************** RUN: #1
# iteration: 0 number of modules: 8116
# iteration: 20 number of modules: 1632
# iteration: 40 number of modules: 1629
# collection done
#
#
# checked 0 modules 0 were found significant.  Modules to check: 1666. Percentage nodes done: 0
# checked 100 modules 98 were found significant.  Modules to check: 1566. Percentage nodes done: 0.579562
# checked 200 modules 195 were found significant.  Modules to check: 1466. Percentage nodes done: 0.692728
# checked 300 modules 295 were found significant.  Modules to check: 1366. Percentage nodes done: 0.749404
# checked 400 modules 395 were found significant.  Modules to check: 1266. Percentage nodes done: 0.79492
# checked 500 modules 493 were found significant.  Modules to check: 1166. Percentage nodes done: 0.835668
# checked 600 modules 591 were found significant.  Modules to check: 1066. Percentage nodes done: 0.867247
# checked 700 modules 689 were found significant.  Modules to check: 966. Percentage nodes done: 0.889843
# checked 800 modules 787 were found significant.  Modules to check: 866. Percentage nodes done: 0.912023
# checked 900 modules 884 were found significant.  Modules to check: 766. Percentage nodes done: 0.930938
# checked 1000 modules 984 were found significant.  Modules to check: 666. Percentage nodes done: 0.946241
# checked 1100 modules 1081 were found significant.  Modules to check: 566. Percentage nodes done: 0.959554
# checked 1200 modules 1173 were found significant.  Modules to check: 466. Percentage nodes done: 0.969764
# checked 1300 modules 1249 were found significant.  Modules to check: 366. Percentage nodes done: 0.978029
# checked 1400 modules 1327 were found significant.  Modules to check: 266. Percentage nodes done: 0.985183
# checked 1500 modules 1376 were found significant.  Modules to check: 166. Percentage nodes done: 0.990971
# checked 1600 modules 1426 were found significant.  Modules to check: 66. Percentage nodes done: 0.996759
# significance check done
#
#
# checking unions of not significant modules, modules to check: 219
# iteration: 0 number of modules: 219
# collection done
#
#
# checking unions of not significant modules done
#
#
# ***************************************************************************
# COLLECTING SIGNIFICANT MODULES DONE
#
# minimality check: 1272 modules to check, run: 0
# minimality check: 283 modules to check, run: 1
# minimality check: 6 modules to check, run: 2
# ***************************************************************************
# MINIMALITY CHECK DONE
# checking similar modules
#
# check unions of modules using community network
#
# iteration: 0 number of modules: 2376
# iteration: 20 number of modules: 1158
# collection done
#
#
# possible fusions to check: 1173
# checked 0 unions. Fused: 1
# checked 100 unions. Fused: 5
# checked 200 unions. Fused: 11
# checked 300 unions. Fused: 16
# checked 400 unions. Fused: 25
# checked 500 unions. Fused: 43
# checked 600 unions. Fused: 48
# checked 900 unions. Fused: 57
# check unions of modules using community network
#
# iteration: 0 number of modules: 2327
# iteration: 20 number of modules: 1113
# collection done
#
#
# possible fusions to check: 1151
# checked 0 unions. Fused: 0
# checked 100 unions. Fused: 1
# checked 200 unions. Fused: 2
# checked 300 unions. Fused: 4
# checked 400 unions. Fused: 9
# checked 500 unions. Fused: 19
# checked 600 unions. Fused: 24
# checked 900 unions. Fused: 26
# checked 1000 unions. Fused: 26
# checking highly intersecting modules
#
# pairs to check: 3542
# minimality check: 8 modules to check, run: 1
# minimality check: 7 modules to check, run: 1
# pairs to check: 848
# minimality check: 7 modules to check, run: 1
# pairs to check: 271
# pairs to check: 65
# pairs to check: 16
# pairs to check: 13
# ***************************************************************************
# CHECK UNIONS AND SIMILAR MODULES DONE
# ******** module_collection ******** 1188 modules. writing...
# DONE   ****************************
# pruning all the modules collected. Partitions found: 1
# getting partition from tp-file: ../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files/partitions_level_0
# 1188 groups found
# 1188 bss found
# checking homeless nodes
# assigning homeless nodes. Homeless at this point: 13534
# assigning homeless nodes. Homeless at this point: 805
# assigning homeless nodes. Homeless at this point: 275
# assigning homeless nodes. Homeless at this point: 260
# assigning homeless nodes. Homeless at this point: 259
# writing final solution in file ../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files/tp
# ******** module_collection ******** 1188 modules. writing...
# DONE   ****************************
# network:: 1447 nodes and 1.41833e+06 stubs;	 average degree = 980.187
# STARTING! HIERARCHICAL LEVEL: 1
# pruning all the modules collected. Partitions found: 0
# getting partition from tp-file: ../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files/partitions_level_1
# 0 groups found
# 0 bss found
# checking homeless nodes
# writing final solution in file ../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files/short_tp1
# ******** module_collection ******** 0 modules. writing...
# DONE   ****************************
# hierarchies done *********
# 474.9299144744873

# %% [markdown]
# # Predicciones

# %%
train, clusters = extract_oslom('../../results/matrix/mentions/edges_comentions_weighted.csv_oslo_files/tp')

# %%
train["id"].nunique()
# Out:
# 43193

# %%
def get_original_user_id(row):
    return total_users[row["id"]]

train["id"] = train.apply(get_original_user_id, axis=1)

# %%
users_train_final = pd.merge(
    left=train,
    right=users_train,
    how='inner',
    left_on="id",
    right_on="id",
    validate="m:1"
)

# %%
users_train_final = users_train_final.loc[:, ["id", "cluster", "unified_place", "latitude", "longitude"]]

# %%
users_train_final = users_train_final.groupby(
        ["id", "unified_place", "latitude", "longitude"]
    )['cluster'].apply(list).reset_index(name='clusters')

# %%
users_train_final.shape
# Out:
# (43193, 5)

# %%
users_train_final.head()
# Out:
#        id                              unified_place   latitude  longitude  \
# 0  624143  ciudad autónoma de buenos aires,argentina -34.613152 -58.377232
# 1  755340                       corrientes,argentina -27.467840 -58.834400
# 2  817969                          córdoba,argentina -31.413500 -64.181053
# 3  819188  ciudad autónoma de buenos aires,argentina -34.613152 -58.377232
# 4  821923                           sao paulo,brasil -23.547501 -46.636108
#
#      clusters
# 0  [368, 691]
# 1       [508]
# 2      [1141]
# 3      [1138]
# 4       [193]

# %%
locations = users_train_final.loc[:, ["unified_place", "latitude", "longitude"]].values
class_names = sorted(users_train_final['unified_place'].unique())

# %%
train["cluster"].nunique()
# Out:
# 1447

# %%
vectorizer = CountVectorizer(
    strip_accents=None,
    lowercase=False,
    analyzer=lambda x: x
)

vector_of_clusters = vectorizer.fit_transform(users_train_final["clusters"]).astype(np.float32)
vector_of_clusters
# Out:
# <43193x1447 sparse matrix of type '<class 'numpy.float32'>'
# 	with 46266 stored elements in Compressed Sparse Row format>

# %%
estimators = [
    {
        "name": "LightGBM",
        "estimator": lgb.LGBMClassifier(n_jobs=1, objective="multiclass", random_state=1500),
        "params_grid": {'max_depth': [8, 80, 200, -1], 'class_weight': ['balanced']}
    },    
    {
        "name": "SVC",
        "estimator": SVC(kernel="rbf", probability=True, random_state=1500),
        "params_grid": {"C": [1, 10, 100], "gamma": [.01, .1], 'class_weight': ['balanced']}
    },
    {
        "name": "DecisionTree",
        "estimator": DecisionTreeClassifier(random_state=1500),
        "params_grid": {'max_depth': [8, 80, 200, 500, None], 'min_samples_leaf': [1], 'class_weight': ['balanced']}
    },
    {
        "name": "RandomForest",
        "estimator": RandomForestClassifier(n_jobs=-1, random_state=1500),
        "params_grid": {'max_depth': [8, 80, 200, 500, None], 'max_features': ['sqrt', 5, 8, 200], 'class_weight': ['balanced_subsample']}
    }
]

# %%
inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
scores = {}
predictions = {}

for estimator in estimators:
    clf = GridSearchCV(
        estimator=estimator["estimator"],
        param_grid=estimator["params_grid"],
        cv=inner_cv,
        n_jobs=-1,
        scoring=['accuracy', 'balanced_accuracy', 'roc_auc_ovo'],
        refit='roc_auc_ovo'
    )
    
    nested_score = cross_validate(
        clf,
        X=vector_of_clusters,
        y=locations[:,0],
        cv=outer_cv,
        n_jobs=-1,
        scoring={
            'accuracy': 'accuracy',
            'balanced_accuracy': 'balanced_accuracy',
            'roc_auc_ovo': 'roc_auc_ovo',
            'accuracy@161': make_scorer(accuracy_161km, greater_is_better=True)            
        }
    )
    
    nested_predict = cross_val_predict(
        clf,
        X=vector_of_clusters,
        y=locations[:,0],
        cv=outer_cv,
        n_jobs=-1,
        method='predict'
    )
        
    scores[estimator["name"]] = nested_score
    predictions[estimator["name"]] = nested_predict

# %%
scores
# Out:
# {'LightGBM': {'fit_time': array([314.83281279, 312.73015976, 312.92243862, 315.60111165,
#          309.51986885]),
#   'score_time': array([13.97157407, 16.37339473, 13.09098482, 15.00097275, 15.33118415]),
#   'test_accuracy': array([0.32622104, 0.32205368, 0.3349725 , 0.32972162, 0.33216637]),
#   'test_balanced_accuracy': array([0.35378362, 0.35236207, 0.36402923, 0.35923187, 0.35753405]),
#   'test_roc_auc_ovo': array([0.81656186, 0.8177084 , 0.8222223 , 0.81933446, 0.82164165]),
#   'test_accuracy@161': array([0.53750625, 0.52600433, 0.56284381, 0.54434072, 0.53480037])},
#  'SVC': {'fit_time': array([14259.58472657, 14258.64268374, 14771.87898922, 14637.47967792,
#          15091.68553829]),
#   'score_time': array([59.49051404, 63.04232931, 52.3462553 , 58.10180926, 54.78739738]),
#   'test_accuracy': array([0.39456576, 0.38714786, 0.38839807, 0.48049675, 0.47470201]),
#   'test_balanced_accuracy': array([0.38199112, 0.37833675, 0.38815243, 0.30243115, 0.30491581]),
#   'test_roc_auc_ovo': array([0.79583795, 0.7942894 , 0.79521082, 0.7889583 , 0.79150767]),
#   'test_accuracy@161': array([0.60610102, 0.58634772, 0.59393232, 0.6367728 , 0.63324164])},
#  'DecisionTree': {'fit_time': array([16.99022603, 16.95063281, 16.6819644 , 16.89769816, 15.66016197]),
#   'score_time': array([5.64438605, 5.9453702 , 5.7704339 , 6.5039978 , 5.58539104]),
#   'test_accuracy': array([0.45307551, 0.43898983, 0.46116019, 0.4578263 , 0.44794532]),
#   'test_balanced_accuracy': array([0.37799978, 0.37827206, 0.38554374, 0.38134149, 0.37909531]),
#   'test_roc_auc_ovo': array([0.81020798, 0.81353386, 0.81702008, 0.81386347, 0.81178538]),
#   'test_accuracy@161': array([0.6141857 , 0.6126021 , 0.62385398, 0.6201867 , 0.61065266])},
#  'RandomForest': {'fit_time': array([2236.4775722 , 2270.03983784, 2262.98691797, 2250.48675776,
#          2259.45052505]),
#   'score_time': array([24.55479574,  4.86967897,  8.27677512, 15.73419046,  9.74934411]),
#   'test_accuracy': array([0.31696949, 0.32305384, 0.3243874 , 0.32847141, 0.33333333]),
#   'test_balanced_accuracy': array([0.38950876, 0.3844581 , 0.39489972, 0.3936418 , 0.38716869]),
#   'test_roc_auc_ovo': array([0.83082531, 0.83138191, 0.83536026, 0.83288857, 0.83274185]),
#   'test_accuracy@161': array([0.54692449, 0.54467411, 0.55800967, 0.56292715, 0.54521964])}}

# %%
f, ax = plt.subplots(nrows=len(predictions), figsize=(25, 20*len(predictions)))
i = 0
f.tight_layout(pad=30.0)

for key in predictions:
    cm = confusion_matrix(locations[:,0], predictions[key], labels=class_names)

    sns.heatmap(
        cm,
        annot=True,
        #linewidths=.5,
        fmt='d',
        robust=True,
        cmap='Blues',
        xticklabels=class_names,
        yticklabels=class_names,
        ax=ax[i]
    )
    
    ax[i].set_title("Menciones: " + key, fontsize=20, fontweight='bold', pad=20)
    ax[i].xaxis.set_tick_params(labelsize=16)
    ax[i].yaxis.set_tick_params(labelsize=16)

    i += 1

# %%
estimators = [
    {
        "name": "BalRandomForest",
        "estimator": BalancedRandomForestClassifier(n_jobs=-1, random_state=42),
        "params_grid": {'max_depth': [8, 80, 200, 500, None], 'max_features': ['sqrt'], 'sampling_strategy': ["all"]}
    }
]

# %%
scores = {}
predictions = {}

for estimator in estimators:
    clf = GridSearchCV(
        estimator=estimator["estimator"],
        param_grid=estimator["params_grid"],
        cv=inner_cv,
        n_jobs=-1,
        scoring=['accuracy', 'balanced_accuracy', 'roc_auc_ovo'],
        refit='roc_auc_ovo'
    )
    
    nested_score = cross_validate(
        clf,
        X=vector_of_clusters,
        y=locations[:,0],
        cv=outer_cv,
        n_jobs=-1,
        scoring={
            'accuracy': 'accuracy',
            'balanced_accuracy': 'balanced_accuracy',
            'roc_auc_ovo': 'roc_auc_ovo',
            'accuracy@161': make_scorer(accuracy_161km, greater_is_better=True)            
        }
    )
    
    print(nested_score)
        
    nested_predict = cross_val_predict(
        clf,
        X=vector_of_clusters,
        y=locations[:,0],
        cv=outer_cv,
        n_jobs=-1,
        method='predict'
    )
        
    scores[estimator["name"]] = nested_score
    predictions[estimator["name"]] = nested_predict
# Out:
# {'fit_time': array([88.95833564, 88.6964035 , 91.20828176, 89.87744808, 88.86435628]), 'score_time': array([10.12071991,  9.41216445,  8.07217002,  7.8391397 ,  7.975703  ]), 'test_accuracy': array([0.39402709, 0.37863179, 0.39541614, 0.37855985, 0.39592498]), 'test_balanced_accuracy': array([0.44068706, 0.4368767 , 0.44907761, 0.44200685, 0.44360486]), 'test_roc_auc_ovo': array([0.8586104 , 0.85852354, 0.86504953, 0.860095  , 0.85960224]), 'test_accuracy@161': array([0.62912374, 0.61210788, 0.62738743, 0.61646214, 0.62317666])}

# %%
scores
# Out:
# {'BalRandomForest': {'fit_time': array([88.95833564, 88.6964035 , 91.20828176, 89.87744808, 88.86435628]),
#   'score_time': array([10.12071991,  9.41216445,  8.07217002,  7.8391397 ,  7.975703  ]),
#   'test_accuracy': array([0.39402709, 0.37863179, 0.39541614, 0.37855985, 0.39592498]),
#   'test_balanced_accuracy': array([0.44068706, 0.4368767 , 0.44907761, 0.44200685, 0.44360486]),
#   'test_roc_auc_ovo': array([0.8586104 , 0.85852354, 0.86504953, 0.860095  , 0.85960224]),
#   'test_accuracy@161': array([0.62912374, 0.61210788, 0.62738743, 0.61646214, 0.62317666])}}

# %%
f, ax = plt.subplots(nrows=len(predictions), figsize=(25, 20*len(predictions)))
i = 0
f.tight_layout(pad=30.0)

for key in predictions:
    cm = confusion_matrix(locations[:,0], predictions[key], labels=class_names)

    sns.heatmap(
        cm,
        annot=True,
        #linewidths=.5,
        fmt='d',
        robust=True,
        cmap='Blues',
        xticklabels=class_names,
        yticklabels=class_names,
        ax=ax
    )
    
    ax.set_title("Menciones: " + key, fontsize=20, fontweight='bold', pad=20)
    ax.xaxis.set_tick_params(labelsize=16)
    ax.yaxis.set_tick_params(labelsize=16)

    i += 1
